# %% [markdown]
# ### 1. 데이터 불러오기 -> df 만들기

# %%
import pandas as pd
# from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from dotenv import load_dotenv

load_dotenv()

# 파일 경로 및 데이터 불러오기
existing_data_path = "./file/테스트 2차자료_상시감사팀.xlsx"
df = pd.read_excel(existing_data_path, header=None)
df = df.iloc[:243]
print(df)
# 컬럼 정의
columns_q = ["idx", "Q1", "Q2", "Q3", "Q4", "Q5", "Q6", "DBRN_NM"]
columns_a = ["idx", "A1", "A2", "A3", "A4", "A5", "A6", "DBRN_NM"]

# 첫 번째 row는 질문 DataFrame
question_df = pd.DataFrame(df.iloc[:1].values, columns=columns_q)

# 나머지 row는 응답 DataFrame
answer_df = pd.DataFrame(df.iloc[1:243].values, columns=columns_a)
df
# Out:
#        0                                                  1  \
# 0     채번  [질문1]\n(본인이 하시는 영업이나 업무중에 리스크 발생가능성이 높고, 영향도가 ...
# 1      1                특이사항 없음\n(청담금융센터------> 현지점 발령 1년차)
# 2      2                                            특이사항 없음
# 3      3                                  특이사항 없음\n(영업 1년차)
# 4      4                                          특이사항 없음\n
# ..   ...                                                ...
# 238  238                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 239  239               입사 전 KB증권,DB증권 인턴경험/ 지점영업 지원(적성에 맞음)
# 240  240                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 241  241                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 242  242         IB영업/법인영업 상품위주 영업/ 입사 후 개인 -> IB -> 법인영업 순
#
#                                                      2  \
# 0    [질문2]\n영업활동을 하면서 내부통제 준수에 어려움이 있으십니까?\n-어려움이 있...
# 1                                     어려운 점 없음\n\n\n4점
# 2                                     어려운 점 없음\n\n\n4점
# 3                                           상동\n\n\n4점
# 4                                     어려운 점 없음\n\n\n4점
# ..                                                 ...
# 238    \n\n서류 미비 거의 발생하지 않으며 발생 시 보완 바로됨\n\n\n\n\n\n4점
# 239   - 없음(강중재 부지점장님 많은 도움을 주고 계심)\n\n - 내부통제 인식 수준...
# 240                 \n\n서류 미비 거의 발생하지 않음\n\n\n\n\n\n5점
# 241  \n\n서류 미비 거의 발생하지 않으나, 발생시 바로 보완완료함\n\n\n\n\n\n5점
# 242   - 라임사태 때 타격 컸음(사모펀드 사건 후 미비 없어짐)\n - 서류간소화 필요...
#
#                                                      3  \
# 0    [질문3]\n영업하는 과정에서 내부통제 절차를 준수하기 위해 개선되어야 할 점은 무...
# 1                                              특이사항 없음
# 2                                              특이사항 없음
# 3                                    특이사항 없음\n(영업 1년차)
# 4                                              특이사항 없음
# ..                                                 ...
# 238  1. 해외주식 증여 단가입력업무 관련 시스템 구축 및 망고매뉴얼 등재 필요(공통)\...
# 239                                                  -
# 240  1. 해외주식 단가입력업무 관련 시스템 구축 및 망고매뉴얼 등재 필요(공통)\n2....
# 241  1. 해외주식 단가입력업무 관련 시스템구축 및 망고매뉴얼 등재 필요(공통)\n2. ...
# 242                                                  -
#
#                                                      4  \
# 0    [질문4]\n과거 또는 현재 지점(센터)에서 영업 및 업무 처리 절차 중에서 부적절...
# 1                          분위기가 너무 좋고 영업활동하기에 최적으로 느껴짐
# 2    * 특이사항없으며, 신한이라는 브랜드를 가지고 그에 따른 혜택을 보고 있다고 생각하...
# 3                                      현 지점 분위기는 매우 좋음
# 4                         적절한 관계로 잘 지내고 있으며 부적절한 관행 없음
# ..                                                 ...
# 238                                                 없음
# 239                                             없음. \n
# 240                                                 없음
# 241                                                 없음
# 242                                             없음. \n
#
#                                                      5  \
# 0    [질문5]\n지점장, 센터장, 본부장 등 상급자로부터 부당한 업무를 지시를 받거나 ...
# 1                                                   없음
# 2                                                   없음
# 3                                                   없음
# 4                                                   상동
# ..                                                 ...
# 238                                                 없음
# 239                                               없음.
# 240                                                 없음
# 241                                                 없음
# 242                                               없음.
#
#                                                      6       7
# 0    [질문6]\n이번 금융사고와 관련하여 평소 회사에 개선이 필요하다고 생각한 것이 있...     NaN
# 1                                                   없음  강남금융센터
# 2    * 이번 사고와는 외적으로 영업과 본사간의 괴리는 있으나, 지점에서 어떠한 일을 진...  강남금융센터
# 3    * 통제시스템의 역할 필요(인적구성):\n전문적인 트레이딩 부서에 대해서는 실질적으...  강남금융센터
# 4    * 직원들의 우울감, 데미지, 대고객 응대에 있어서 사기저하\n* 관리감독할 수 있...  강남금융센터
# ..                                                 ...     ...
# 238                                            순환보직 필요  인천금융센터
# 239                              - 특별히 생각해 본 적 없음(공부중)  인천금융센터
# 240                업무관련 부서에 장기근무 직원 많아 소통 어려움. 순환보직 필요  인천금융센터
# 241                              업무팀 순환보직 필요(PWM ↔리테일)  인천금융센터
# 242                      부서수익 과하게 부여 (내부통제 측면에서 리스크하다)  인천금융센터
#
# [243 rows x 8 columns]
#        0                                                  1  \
# 0     채번  [질문1]\n(본인이 하시는 영업이나 업무중에 리스크 발생가능성이 높고, 영향도가 ...
# 1      1                특이사항 없음\n(청담금융센터------> 현지점 발령 1년차)
# 2      2                                            특이사항 없음
# 3      3                                  특이사항 없음\n(영업 1년차)
# 4      4                                          특이사항 없음\n
# ..   ...                                                ...
# 238  238                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 239  239               입사 전 KB증권,DB증권 인턴경험/ 지점영업 지원(적성에 맞음)
# 240  240                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 241  241                         책임자 부재시 승인 프로세스 개선 필요 (공통)
# 242  242         IB영업/법인영업 상품위주 영업/ 입사 후 개인 -> IB -> 법인영업 순
#
#                                                      2  \
# 0    [질문2]\n영업활동을 하면서 내부통제 준수에 어려움이 있으십니까?\n-어려움이 있...
# 1                                     어려운 점 없음\n\n\n4점
# 2                                     어려운 점 없음\n\n\n4점
# 3                                           상동\n\n\n4점
# 4                                     어려운 점 없음\n\n\n4점
# ..                                                 ...
# 238    \n\n서류 미비 거의 발생하지 않으며 발생 시 보완 바로됨\n\n\n\n\n\n4점
# 239   - 없음(강중재 부지점장님 많은 도움을 주고 계심)\n\n - 내부통제 인식 수준...
# 240                 \n\n서류 미비 거의 발생하지 않음\n\n\n\n\n\n5점
# 241  \n\n서류 미비 거의 발생하지 않으나, 발생시 바로 보완완료함\n\n\n\n\n\n5점
# 242   - 라임사태 때 타격 컸음(사모펀드 사건 후 미비 없어짐)\n - 서류간소화 필요...
#
#                                                      3  \
# 0    [질문3]\n영업하는 과정에서 내부통제 절차를 준수하기 위해 개선되어야 할 점은 무...
# 1                                              특이사항 없음
# 2                                              특이사항 없음
# 3                                    특이사항 없음\n(영업 1년차)
# 4                                              특이사항 없음
# ..                                                 ...
# 238  1. 해외주식 증여 단가입력업무 관련 시스템 구축 및 망고매뉴얼 등재 필요(공통)\...
# 239                                                  -
# 240  1. 해외주식 단가입력업무 관련 시스템 구축 및 망고매뉴얼 등재 필요(공통)\n2....
# 241  1. 해외주식 단가입력업무 관련 시스템구축 및 망고매뉴얼 등재 필요(공통)\n2. ...
# 242                                                  -
#
#                                                      4  \
# 0    [질문4]\n과거 또는 현재 지점(센터)에서 영업 및 업무 처리 절차 중에서 부적절...
# 1                          분위기가 너무 좋고 영업활동하기에 최적으로 느껴짐
# 2    * 특이사항없으며, 신한이라는 브랜드를 가지고 그에 따른 혜택을 보고 있다고 생각하...
# 3                                      현 지점 분위기는 매우 좋음
# 4                         적절한 관계로 잘 지내고 있으며 부적절한 관행 없음
# ..                                                 ...
# 238                                                 없음
# 239                                             없음. \n
# 240                                                 없음
# 241                                                 없음
# 242                                             없음. \n
#
#                                                      5  \
# 0    [질문5]\n지점장, 센터장, 본부장 등 상급자로부터 부당한 업무를 지시를 받거나 ...
# 1                                                   없음
# 2                                                   없음
# 3                                                   없음
# 4                                                   상동
# ..                                                 ...
# 238                                                 없음
# 239                                               없음.
# 240                                                 없음
# 241                                                 없음
# 242                                               없음.
#
#                                                      6       7
# 0    [질문6]\n이번 금융사고와 관련하여 평소 회사에 개선이 필요하다고 생각한 것이 있...     NaN
# 1                                                   없음  강남금융센터
# 2    * 이번 사고와는 외적으로 영업과 본사간의 괴리는 있으나, 지점에서 어떠한 일을 진...  강남금융센터
# 3    * 통제시스템의 역할 필요(인적구성):\n전문적인 트레이딩 부서에 대해서는 실질적으...  강남금융센터
# 4    * 직원들의 우울감, 데미지, 대고객 응대에 있어서 사기저하\n* 관리감독할 수 있...  강남금융센터
# ..                                                 ...     ...
# 238                                            순환보직 필요  인천금융센터
# 239                              - 특별히 생각해 본 적 없음(공부중)  인천금융센터
# 240                업무관련 부서에 장기근무 직원 많아 소통 어려움. 순환보직 필요  인천금융센터
# 241                              업무팀 순환보직 필요(PWM ↔리테일)  인천금융센터
# 242                      부서수익 과하게 부여 (내부통제 측면에서 리스크하다)  인천금융센터
#
# [243 rows x 8 columns]

# %% [markdown]
# ### 2. 직원의견 요약 및 키워드 추출

# %%
import pandas as pd
import json
import os
import time
# from openai import OpenAI
from openai._client import OpenAI

def prepare_batch(records):
    """
    주어진 레코드 리스트를 OpenAI 배치 처리 API에 적합한 메시지 리스트로 변환.
    """
    messages_batch = []
    for idx, record in enumerate(records):
        custom_id = f"request-{idx + 1}"
        body = {
            "model": "gpt-4o",  # 모델 이름
            "messages": [
                {
                    "role": "system",
                    "content": f"""
당신은 회사 감사실의 직원이자 리스크 관리를 위한 기획자입니다. 직원들에게 6개의 질문을 하고 답변을 받았습니다. 이제 각 질문과 그에 대한 답변을 분석해야 합니다.

# 작업 지시사항:

각 질문과 해당 답변을 인식하십시오.
각 답변을 간결하고 명확하게 요약하고 여러 내용이 있을 경우 모두 출력하십시오. 
요약된 내용에서 3~5개의 주요 키워드를 추출하십시오.
결과를 아래의 JSON 형식으로 출력하십시오.

[출력 형식]
무조건 6개의 딕셔너리 결과가 나와야 합니다.(질문 1~6)

{{
  "질문 1": {{
    "summary": ["요약1","요약2","요약3"...]
    "keywords": ["키워드1", "키워드2", "키워드3"..]
  }},
  "질문 2": {{
    "summary": ["요약1","요약2","요약3"...]
    "keywords": ["키워드1", "키워드2", "키워드3"..]
  }},
  ...
}}

[주의사항]
내용을 보고 불필요한 내용만 존재할 경우 요약, 키워드는 빈칸으로 출력합니다.
입력되는 질문과 답변은 마크다운 형식을 따릅니다.
요약은 각 답변의 핵심 내용을 포괄해야 합니다.
요약에는 점수 내용은 표시하지 않습니다.
키워드는 답변의 주요 주제나 이슈를 반영해야 합니다.
키워드는 요약 내용에서 추출합니다.
JSON 형식이 올바르게 구성되도록 유의하십시오.
출력 시 불필요한 문자나 설명을 포함하지 마십시오.
답변에 xxx 없다는 내용을 표현할 경우 요약 및 키워드에 작성하지 않습니다.
내부통제 관련 부족한 부분이나 의견을 보기 위한 요청이므로 문제점이라고 생각하는 키워드만 추출해주세요.
                """,
                },
                {
                    "role": "user",
                    "content": f"""
[질문 & 답변]

## 질문 1
{record['Q1']}

### 답변 1
{record['A1']}

## 질문 2
{record['Q2']}

### 답변 2
{record['A2']}

## 질문 3
{record['Q3']}

### 답변 3
{record['A3']}

## 질문 4
{record['Q4']}

### 답변 4
{record['A4']}

## 질문 5
{record['Q5']}

### 답변 5
{record['A5']}

## 질문 6
{record['Q6']}

### 답변 6
{record['A6']}

""",
                },
            ],
            "max_tokens": 1000,
        }
        message = {
            "custom_id": custom_id,
            "method": "POST",
            "url": "/v1/chat/completions",
            "body": body,
        }
        messages_batch.append(message)
    return messages_batch


def process_batches(client, records, batch_size):
    """
    주어진 레코드를 OpenAI 배치 처리 API에 전달하고 결과를 처리.
    """
    results = []
    for batch_start in range(0, len(records), batch_size):
        batch = records[batch_start : batch_start + batch_size]
        messages_batch = prepare_batch(batch)

        # JSONL 파일로 저장
        with open("batchinput.jsonl", "w", encoding="utf8") as file:
            for item in messages_batch:
                json_string = json.dumps(item, ensure_ascii=False)
                file.write(json_string + "\n")

        # Batch 파일 생성
        batch_input_file = client.files.create(
            file=open("batchinput.jsonl", "rb"), purpose="batch"
        )
        batch_input_file_id = batch_input_file.id

        # Batch 생성
        batch_info = client.batches.create(
            input_file_id=batch_input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h",
            metadata={"description": "batch job"},
        )

        # Batch 상태 확인 및 결과 다운로드
        while True:
            batch_status = client.batches.retrieve(batch_info.id).status

            if batch_status == "completed":

                # 기존 데이터 프레임 df 에 llm으로부터 받아온 답변을 추가하기 위한 index
                idx = 0

                print(f"Batch {batch_info.id} processing is completed.")

                # 출력 파일 다운로드
                output_file_id = client.batches.retrieve(batch_info.id).output_file_id
                if output_file_id:
                    result = client.files.content(output_file_id).content
                    result_file_name = f"./batch_results_{batch_start}.jsonl"

                    with open(result_file_name, "wb") as file:
                        file.write(result)

                    print("Output file downloaded:", result_file_name)

                    # 결과 읽기
                    with open(result_file_name, "r", encoding="utf-8") as file:
                        for line in file:
                            json_object = json.loads(line.strip())
                            results.append(json_object)
                break

            elif batch_status in ["failed", "cancelled"]:
                print(f"Batch {batch_info.id} processing failed or was cancelled.")
                break

            else:
                print(
                    f"Batch {batch_info.id} is in progress... Current status: {batch_status}"
                )
                time.sleep(10)

    return results, batch_info


records = [
    {
        "Q1": question_df.loc[0, "Q1"],
        "Q2": question_df.loc[0, "Q2"],
        "Q3": question_df.loc[0, "Q3"],
        "Q4": question_df.loc[0, "Q4"],
        "Q5": question_df.loc[0, "Q5"],
        "Q6": question_df.loc[0, "Q6"],
        "A1": answer_df.loc[i, "A1"],
        "A2": answer_df.loc[i, "A2"],
        "A3": answer_df.loc[i, "A3"],
        "A4": answer_df.loc[i, "A4"],
        "A5": answer_df.loc[i, "A5"],
        "A6": answer_df.loc[i, "A6"],
    }
    for i in range(len(answer_df))
]

# 클라이언트 생성 및 배치 처리 실행
client = OpenAI()
batch_size = 3000
results, batch_info1 = process_batches(client, records, batch_size)
# Out:
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: validating
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: in_progress
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: finalizing
# Batch batch_6746ce63e8748190ba32e8989db1afe0 is in progress... Current status: finalizing
# Batch batch_6746ce63e8748190ba32e8989db1afe0 processing is completed.
# Output file downloaded: ./batch_results_0.jsonl

# %%
len(df)
# Out:
# 243

# %%
import re


def save_results_to_dataframe(df, results):
    """
    JSONL 파일 내용을 데이터프레임으로 저장.
    """

    # JSON 파싱

    try:

        # data = json.loads(results)
        results = results

    except json.JSONDecodeError as e:

        print("JSON Decode Error:", e)

        print("Response content:", results)

    i = 1

    for result in results:

        # 결과로 회신받은 jsonl 을 line 별로 처리하여 데이터 추출
        content = result["response"]["body"]["choices"][0]["message"]["content"]
        # json 을 dict 로 불러올 경우 발생할 수 있는 오류 인자 제거
        content = content.strip()

        if not content.startswith("{") or not content.endswith("}"):
            # JSON만 추출
            json_match = re.search(r"\{.*\}", content, re.DOTALL)
            if json_match:
                content = json_match.group(0)
            else:
                print("No JSON object found in response.")
                print("Response content:", content)
                raise ValueError("Response is not a valid JSON format.")
        
        # 쉼표가 누락된 경우 수정
        def fix_missing_commas(json_string):
            # 줄바꿈 후 중괄호가 나오는 경우 수정
            fixed = re.sub(r"(?<![:,\[\{\s])(\s*[\{\[])", r",\1", json_string)
            # 중괄호 전에 누락된 쉼표 수정
            fixed = re.sub(r"([\}\]])\s*([\{\[])",
                           r"\1,\2", fixed)
            
            fixed = re.sub(
                r'(\])\s*("[a-zA-Z가-힣0-9_-]+")',
                r'\1,\2',
                fixed
            )
            fixed = fixed.replace(',{', '{')
            return fixed

        content = fix_missing_commas(content)

        # json 을 읽어와 dict 형테로 저장
        try :
            data = json.loads(content)
        except json.JSONDecodeError as e:
            print(content)
            print(i)
        for k in range(1, 7):

            question_key = f"질문 {k}"

            if question_key in data:

                question_data = data[question_key]

                # Summary 변환

                summary_list = question_data["summary"]

                formatted_summary = "\n".join(
                    [f"{i+1}. {summary}" for i, summary in enumerate(summary_list)]
                )

                df.at[i, f"s{k}"] = formatted_summary

                # Keywords 변환

                keywords_list = question_data["keywords"]

                formatted_keywords = "\n".join(
                    [f"{i+1}. {keyword}" for i, keyword in enumerate(keywords_list)]
                )

                df.at[i, f"k{k}"] = formatted_keywords

            else:

                df.at[i, f"s{k}"] = "N/A"

                df.at[i, f"k{k}"] = "N/A"

        i += 1
    return df

# %%
df = save_results_to_dataframe(df, results)
df_copy = df
df_copy = df_copy[1:]
df_copy.rename(columns={0: "idx"}, inplace=True)
# Out:
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\1682641977.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_copy.rename(columns={0: "idx"}, inplace=True)

# %%
# df_keyword = pd.DataFrame(
#     df_copy.values, columns=["idx", "k1", "k2", "k3", "k4", "k5", "k6"]
# )
columns = ["idx", "k1", "k2", "k3", "k4", "k5", "k6"]
df_keyword = df_copy[columns]
# k1~k6 컬럼에 있는 키워드를 정리하는 함수


# 숫자 제거 및 키워드 리스트로 변환하는 함수
def process_keywords(col):
    if pd.notna(col):  # 값이 NaN이 아닌 경우 처리
        return [
            item.split(". ", 1)[1] if ". " in item else item for item in col.split("\n")
        ]
    return []


# 각 km_1 ~ km_6에 저장
for i in range(1, 7):
    col_name = f"k{i}"  # 기존 컬럼 이름
    new_col_name = f"km_{i}"  # 새로운 컬럼 이름
    df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)

# 모든 키워드를 합쳐서 km_f에 저장
df_keyword["km_f"] = df_keyword[[f"km_{i}" for i in range(1, 7)]].sum(axis=1)


# 빈 값(",")을 제거하는 함수
def remove_empty_keywords(keywords):
    return [kw.strip() for kw in keywords if kw.strip() not in [",", ""]]


# 컬럼에 함수 적용
df_keyword["km_f"] = df_keyword["km_f"].apply(remove_empty_keywords)
df_keyword.drop_duplicates(subset=["km_f"], inplace=True)

# 결과 출력
print(df_keyword["km_f"])
df_keyword.to_csv("keyword.csv")
# Out:
# 1                                                     []
# 2      [브랜드 혜택, 개인적 영업 타격, 영업과 본사 간 괴리, 일률적인 절차 적용, 투...
# 3                               [준법 통제, 인적 구성, 내부 통제 부족]
# 4                    [우울감, 젊은 인력 구성, 정서적 연구, 로열티, 직원 사기]
# 5                                    [KPI 달성, 심적 부담, 모범]
#                              ...
# 237                [국내주식, 퇴직연금, 제도적 변화, 부서수익, 내부통제, 리스크]
# 238    [승인 절차, 책임자 부재, 개선 필요, 시스템 구축, 전자문서, 매뉴얼 정비, 담...
# 240    [승인 프로세스, 책임자 부재, 개선 필요, 시스템 구축, 업무 개선, 전자문서, ...
# 241    [책임자 부재, 승인 프로세스, 개선, 서류 미비, 보완 완료, 해외주식 단가입력,...
# 242    [IB영업, 법인영업, 리스크, 라임사태, 서류간소화, 법인 비딩, 부서수익, 내부...
# Name: km_f, Length: 236, dtype: object
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword[new_col_name] = df_keyword[col_name].apply(process_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword["km_f"] = df_keyword[[f"km_{i}" for i in range(1, 7)]].sum(axis=1)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword["km_f"] = df_keyword["km_f"].apply(remove_empty_keywords)
# C:\Users\shic\AppData\Local\Temp\ipykernel_20544\964512619.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_keyword.drop_duplicates(subset=["km_f"], inplace=True)

# %% [markdown]
# ### 3. 키워드별 직원 맵핑, 지점 맵핑

# %%
import pandas as pd
from konlpy.tag import Okt


df_keyword = pd.read_csv("./keyword.csv")
df_keyword


okt = Okt()
print(okt.morphs("안녕하세요. 저는 자연어 처리를 좋아합니다."))
# Out:
# ['안녕하세요', '.', '저', '는', '자연어', '처리', '를', '좋아합니다', '.']

# %%
df_keyword.dtypes
# Out:
# Unnamed: 0     int64
# idx            int64
# k1            object
# k2            object
# k3            object
# k4            object
# k5            object
# k6            object
# km_1          object
# km_2          object
# km_3          object
# km_4          object
# km_5          object
# km_6          object
# km_f          object
# dtype: object

# %%
# 키워드 합치기
import ast

# df 에 저장된 리스트 형식 텍스트를 실제 list 로 변환
merged_keywords = []
df_keyword["km_f"] = df_keyword["km_f"].apply(ast.literal_eval)
for i in range(1,7):
    df_keyword[f"km_{i}"] = df_keyword[f"km_{i}"].apply(ast.literal_eval)

for row in df_keyword["km_f"]:

    for i in row:

        merged_keywords.append(i)


merged_keywords
# Out:
# ['브랜드 혜택',
#  '개인적 영업 타격',
#  '영업과 본사 간 괴리',
#  '일률적인 절차 적용',
#  '투명성 향상',
#  '준법 통제',
#  '인적 구성',
#  '내부 통제 부족',
#  '우울감',
#  '젊은 인력 구성',
#  '정서적 연구',
#  '로열티',
#  '직원 사기',
#  'KPI 달성',
#  '심적 부담',
#  '모범',
#  '지점 구조',
#  '부당한 지시',
#  '부적절한 업무',
#  '내부통제 준수',
#  '직원 인식',
#  '내부통제 절차',
#  '면담 프로세스',
#  '내부통제',
#  '문의',
#  '조치 요구',
#  '부적절한 업무 절차',
#  '좋은 분위기',
#  '상식적인 프로세스',
#  '대출',
#  '민원',
#  '트라우마',
#  '경력 부족',
#  '내부통제 절차',
#  '시스템',
#  '개선 필요',
#  '인수인계',
#  '교육',
#  '승인 절차',
#  '상품 선가입',
#  '미비점',
#  '보완',
#  '전자화문서',
#  '가입 서류',
#  '유선업무',
#  '신한계열사 입금',
#  '메신저 기록',
#  '유선 녹취 없음',
#  '상품 선가입 미비',
#  '보완 충분',
#  '계열사 업무',
#  '메신저 처리 관행',
#  '상품 선가입',
#  '미비함',
#  '보완',
#  '퇴직연금',
#  '자동발송',
#  '기능 추가',
#  '사고 발생',
#  '최종 결론 공개',
#  '정보 공개',
#  '인감',
#  '날인',
#  '보관',
#  '상품 선가입',
#  '내부통제',
#  '수기 업무',
#  '해외주식',
#  '입력 이슈',
#  '대출 자금',
#  '예수금 대체',
#  '녹취 점검',
#  '전문투자자 등록',
#  '계좌 개설',
#  '리스크',
#  '권리 누락',
#  '만기 누락',
#  '책임소재 불분명',
#  '사고 사례',
#  '경각심',
#  '게시물 필요',
#  '상품 가입 미비',
#  '절차 문제',
#  'PB 교육',
#  '지점 축소',
#  '업무 부담',
#  '금융상품 가입',
#  '처리 지연',
#  '큰 금액 처리',
#  '내부통제 준수',
#  '직원 인식',
#  '완벽하지 않음',
#  '시장 리스크 관리',
#  '내부통제',
#  '영업',
#  '인식 수준',
#  '해외주식양도세',
#  '전화녹취 개선',
#  '내방 업무',
#  '전문가 영업',
#  '인사 부서배치',
#  '성과급 문제',
#  'IT 문제',
#  '개인 포기',
#  'LP업무',
#  '내부통제',
#  '권한',
#  '한도',
#  '내부통제',
#  '불확실성',
#  '내부통제',
#  '교육 접근성',
#  '자료',
#  '보고체계',
#  '주기적 보고',
#  'IT 문제',
#  '내부통제 준수',
#  '포기 요인',
#  '자기사람 채용',
#  '견제와 균형',
#  '영업 방향성',
#  '롱텀 근무',
#  'YES맨 문화',
#  '철저한 검증과 통제',
#  '파워 집중',
#  '순환보직',
#  '투자 시간',
#  '인당 노력',
#  '내부통제',
#  '강압적 지시',
#  '모욕',
#  '묵인',
#  'IB연계 영업',
#  '리스크',
#  '기업금융',
#  '수익 손실',
#  '협업 문제',
#  '법규준수',
#  '외부영업',
#  '업무처리 어려움',
#  '자발적 야근',
#  '본사부서 역할',
#  '모호성',
#  'R&R',
#  '파생상품 통제',
#  '시재관리',
#  '인력관리 개선',
#  '대출업무 시간',
#  '심사부 승인 지연',
#  '내부통제 준수',
#  '본사 사고',
#  '내부통제 강화',
#  '성과급체계',
#  '경력직원 검증',
#  '내부통제 강화',
#  '운영리스크',
#  '자금 사고',
#  '매매 체크',
#  '리스크',
#  '경력직',
#  '비도덕성',
#  '고객정보 노출',
#  '비밀번호 없이 전환',
#  '사고 위험성',
#  '중징계',
#  '인사관리',
#  '고객정보',
#  '수기 업무',
#  'Back-to-Back 거래',
#  '확인 절차',
#  '퇴직연금',
#  '채권 매도',
#  '개별 공시',
#  '결제 간소화',
#  '재무회계 통제',
#  '법인선물옵션부 퇴사',
#  '인적 쇄신',
#  '시스템 부재',
#  '모럴헤저드',
#  '녹취 기준',
#  '매매주문',
#  '명확한 해석',
#  '내부통제 수준',
#  '현 사태',
#  '신입사원',
#  '대출 등급',
#  '리스크',
#  '단기성과',
#  '고객 신뢰',
#  '언론보도',
#  'KPI 변경',
#  '인적 쇄신',
#  '한도 초과',
#  '시스템 문제',
#  '한도 설정',
#  '신용 등급',
#  '대출 등급',
#  '형평성 문제',
#  '평판 리스크',
#  '영업력 저하',
#  '시스템 문제',
#  '주문 실수',
#  '전화 대리',
#  '리스크 노출',
#  'BEP 상승',
#  '사기 저하',
#  '전문가 부족',
#  '인적쇄신 필요',
#  '조직변경 문제',
#  '법선 수익부서 제외',
#  'OTC 거래',
#  '계약 과정',
#  '체계적인 확립',
#  '고유자산',
#  'Account Risk',
#  '전수조사',
#  'MTS 사용 불편',
#  '전문가 부족',
#  '답변 어려움',
#  '순환보직',
#  '인력 개선',
#  'R&R 명확화',
#  '부서와의 합의',
#  '관련 내용 공지',
#  '사규 재개정',
#  '업무 매뉴얼',
#  '시스템 개선',
#  '내부통제 강화',
#  '조직도 개편',
#  '기준 불투명',
#  '채권금리',
#  '이율',
#  '조직 세분화',
#  '부서명 변경',
#  '업무문의',
#  '순환보직',
#  '리스크 확인',
#  '해외주식',
#  '시스템 개선',
#  '매뉴얼',
#  '알람',
#  '신분증',
#  '의사소통',
#  '법무실',
#  '법률 이슈',
#  '소통 문제',
#  '신용 대출',
#  '고객 관리',
#  '채권상품',
#  '금리 경쟁력',
#  '기준 부재',
#  '해외주식',
#  '업무 퀄리티',
#  '직원 교육',
#  '책임감',
#  '직원',
#  '순환보직',
#  '승인 프로세스',
#  '단가 입력',
#  '전자화문서',
#  '화면 업데이트',
#  '업무공지',
#  '인수인계서',
#  '업무 교육',
#  '전담 조직',
#  '통제 시스템',
#  '승인 프로세스',
#  '해외주식 시스템',
#  '매뉴얼 미비',
#  'ODS시스템',
#  '해외주식 프로그램',
#  '연금저출 시스템',
#  '순환보직',
#  'ODS시스템',
#  '사용율 낮음',
#  '프로세스 재정비',
#  '교섭수수료 누락',
#  '리츠 대출 문제',
#  '민원 발생 가능',
#  '순환보직',
#  '리스크 확인',
#  '업무매뉴얼 부족',
#  '시스템 개선 필요',
#  '시스템 사용 부족',
#  '데이터 오류',
#  '시스템 개발 필요',
#  '퇴직연금 화면 개선',
#  '수기업무 위험',
#  '업무 일원화 필요',
#  '내부통제 권한 부족',
#  '영업성과',
#  '외부활동',
#  '어려움',
#  '상품서류 간소화',
#  'S-MEET 시스템',
#  '시스템 개선',
#  '미스터리쇼핑',
#  '온라인가입',
#  '내부통제',
#  '개인성향',
#  'KPI 드라이브',
#  '중장기성 상품',
#  '수작업',
#  '협의금리',
#  '환전우대',
#  '디지털창구',
#  '개인정보 보호',
#  '주민번호 마스킹',
#  '크로스 체크',
#  '로테이션',
#  '장기근속자',
#  '환전우대',
#  '비관리계좌',
#  '연금 해지 계좌',
#  '컴플라이언스',
#  'CDD 승인 지연',
#  '점심시간 교대',
#  '연금저축',
#  'IRP',
#  '세금 문제',
#  '전문팀 필요',
#  'PB 권한',
#  '문의 필요',
#  '서류 문제',
#  '대직자 부재',
#  '담당자 찾기 어려움',
#  '교육 필요',
#  '파견인원 부족',
#  '인원 확충',
#  '담당자 찾기 어려움',
#  '대직자 부재',
#  '교육 필요성',
#  '파견인원 부족',
#  '인원 확충',
#  '신규 채용',
#  'PB',
#  '골드넷+ 교육',
#  '수작업',
#  '업무집중화팀',
#  '인사배치',
#  '본사직원',
#  '시니어부족',
#  '금융상품',
#  '판매 프로세스',
#  '체크',
#  '시스템',
#  '권한 통제',
#  '업무처리자',
#  '업무개발자',
#  '리스크',
#  '주식영업',
#  '내부고발자',
#  '포상',
#  '솜방망이 처벌',
#  '금융사고',
#  '책임',
#  '권한 부여자',
#  '인사 인력배치',
#  '시니어',
#  '업무 환경',
#  '증권 본업',
#  '해외주식 정보력',
#  'KPI 조정',
#  '경쟁력 데이터',
#  '타사 참고',
#  '데이터 개선',
#  '기획자 책임',
#  '잘못 설계',
#  '한도 부여자',
#  '퇴직연금',
#  '해외주식',
#  '리스크',
#  '업무과실',
#  '서류 미비',
#  '크로스체크',
#  '승인 절차',
#  '고객지원팀장',
#  '법인카드 리스크',
#  '인식 변화',
#  '사례중심교육',
#  '국내주식 약세장',
#  '회의감',
#  '대비',
#  'KPI 방향성',
#  '시점 부적합',
#  '영업강조',
#  '무리한 매매',
#  '주식영업',
#  '리스크 발생',
#  '영향도 큼',
#  'KPI 리스크',
#  '그룹 협업 부족',
#  '경영진 변화 필요',
#  '과도한 목표',
#  '금융사고',
#  '인센티브 문제',
#  '조직적 구조 문제',
#  '조직 부정적 관행',
#  '인센티브 구조 문제',
#  '부서명 변경',
#  '주기적 인사이동',
#  '금융상품 절차 부족',
#  '업무 지원 필요',
#  'HTS 화면 차이',
#  '채권부 수익구조',
#  '해외주식 자료 부족',
#  '고객 이탈 가능성',
#  '프로세스 세부 검토',
#  '업무 권한 과다',
#  '리더십 부재',
#  '내부통제',
#  '외부활동 위축',
#  '인적쇄신',
#  '내부통제 재정립',
#  '리더십 부재',
#  '단기 성과주의',
#  '내부통제 문제',
#  '법인자금 유출',
#  '금융사고',
#  '법인영업 위축',
#  '평판 개선',
#  '이미지 쇄신',
#  '강압적 지시',
#  '평가와 징계',
#  '성과급 연동',
#  '승인 절차',
#  '구조적 문제',
#  '수익부서',
#  '내부통제 이해 부족',
#  '평판 리스크',
#  '센터장',
#  '영업 우선',
#  '컨트롤타워 권한',
#  '부서',
#  '담당자 찾기',
#  '퇴직연금',
#  '업무 어려움',
#  '전문팀제 필요',
#  '리스크 발생',
#  '고객 입금',
#  '재무관리부 안내',
#  '대직자 부재',
#  '업무 문의',
#  '개인연금',
#  '유예기간',
#  '영업전환',
#  '고지팀',
#  '연금 업무',
#  '전문팀 통합',
#  '절차 개선',
#  'PB 인식',
#  '부적절한 경향',
#  '무시',
#  '권위적 PB',
#  '고충',
#  '외부사 협업 기피',
#  '조직 편성 변경',
#  '내부통제 허술',
#  '수익 중심 경영',
#  '융통성 결여',
#  '단기 성과',
#  '전략 부재',
#  'KPI 일관성',
#  '내부통제',
#  '과도한 감사',
#  '경위서 제출 요구',
#  '인적 문제',
#  '직원 불만',
#  '인사라인 부작용',
#  '수익부서 지정 문제',
#  '해외주식',
#  '단가 입력',
#  '수기 업무',
#  '미비 보완',
#  '보완완료',
#  '수기잔액증명서',
#  '단가 수기입력',
#  '절차 개선',
#  '고객지원팀장',
#  '업무량 과다',
#  '업무매뉴얼 필요',
#  '시스템 예방',
#  '법인카드',
#  '사용할당 과다',
#  '결재 절차',
#  '본사 담당자 부재',
#  '매뉴얼 미흡',
#  '통제 확인 시스템',
#  '알럿 필요',
#  '업무적정',
#  '3인 체제',
#  '리스크 발생',
#  '업무처리 지연',
#  '고객신뢰 하락',
#  '퇴직연금 매도업무',
#  '고객 이동',
#  '시스템 불만',
#  '타사 시스템 차이',
#  '미비한 업무절차',
#  '상품 가입 보완 부족',
#  '업무전문성',
#  '사고예방',
#  '순환보직 제도',
#  '이슈 사모상품',
#  '고객 설명',
#  '성과급 회수',
#  '내부 통제 점검',
#  '상품부서',
#  '위험도 정보',
#  '검증 부족',
#  '투자상담사',
#  '고객 자금 횡령',
#  '라임',
#  '헤리티지',
#  '신뢰 감소',
#  '주문 실수',
#  '불완전 판매',
#  '담보 관리',
#  '광고 가이드라인',
#  '투자 권유 가이드라인',
#  '대리인 등록 업데이트',
#  '법인 인감',
#  '사용인감 효력',
#  '외국인 업무',
#  '자동 번역',
#  '민원 발생',
#  '내부통제',
#  '미비서류 보완',
#  '해외주식 프로세스',
#  '시스템 개선',
#  'AI 시스템',
#  '순환보직',
#  '전문가 부재',
#  '시뮬레이션 데이터',
#  '고객 민원',
#  '시스템 개선',
#  '매뉴얼 등록',
#  '순환보직',
#  '전문가 필요',
#  '전문 인력 부족',
#  '지점 담당자 비효율',
#  '시스템 사용 어려움',
#  '녹취 장비 문제',
#  '업무 프로세스 개선',
#  '서류 과다',
#  '절차 개선 필요',
#  '순환보직',
#  '조직개편 필요',
#  '리스크 확인 필요',
#  '책임자 승인 프로세스',
#  '신고 누락 리스크',
#  '시스템 알람 기능',
#  '프로세스 개선',
#  '시스템 업데이트',
#  '업무 매뉴얼',
#  '전자화문서',
#  '시스템 교육',
#  '순환보직',
#  '금융상품 서류',
#  '녹취',
#  '내부 통제',
#  '팝업 시스템',
#  '본사 대응',
#  '책임 회피',
#  '서류 복잡성',
#  '리스크 상품',
#  '판매 금지',
#  '인사 문제',
#  '인력 배치',
#  '철저한 감사',
#  '고객 동의 없는 등록',
#  '관리자 등록',
#  '유치자 등록',
#  '녹취 중복',
#  '서류 중복',
#  '시간 소모',
#  '증빙 없는 주문',
#  '부적절한 관행',
#  '주문 관행',
#  '회사북 사용',
#  '자금 사용 점검',
#  '철저한 점검',
#  '부서별 협업',
#  '사건 반복',
#  '임원 모럴헤저드',
#  '관리 시스템 부재',
#  '내부 인재 중용',
#  '평판 리스크 하락',
#  'KPI 설정',
#  '난국',
#  '개선 필요',
#  '불만',
#  '면담 불필요',
#  '내부통제 재정립',
#  '전문성 부족',
#  '사건사고',
#  '인사 문제',
#  '지점 감사',
#  '내부통제 과다',
#  '고객 신뢰',
#  '승인 프로세스',
#  '대주주 대출 시스템',
#  '신용/대출 시뮬레이션',
#  '단가 입력 프로세스',
#  '전자문서 고도화',
#  '전자화문서 시스템',
#  '순환보직',
#  '직원의지',
#  '승인 프로세스',
#  '대주주 대출',
#  '시스템 구축',
#  '해외주식 프로세스',
#  '공모주 업무',
#  '자동이체 환불',
#  '시스템 일원화',
#  '업무시스템',
#  '매매시스템',
#  '수익구조 개선',
#  '벤치마킹',
#  '더블카운팅',
#  '상품 분쟁 예방',
#  '대면 녹취 점검',
#  '완전판매 확인',
#  'ODS 시스템',
#  '신분증 인식',
#  '녹취 시스템',
#  '관리자 감독 역할',
#  '관리와 영업 분리',
#  '팀 인센티브 제도',
#  '승인 프로세스',
#  '대주주 대출',
#  '업무 시스템',
#  '시뮬레이션 화면',
#  '시스템 개선',
#  '데이터 검증',
#  '화면 안내',
#  '업무 교육',
#  '승인 프로세스',
#  '대주주 대출',
#  '가입서류 보관',
#  '해외주식 입력',
#  '전자문서 고도화',
#  '순환보직',
#  '인수인계서 확대',
#  '팀장 부재',
#  '본사 부서 불통',
#  '고객 불만',
#  '내부통제',
#  '전산시스템 불안정',
#  '직원 인식 부족',
#  '수기 처리 업무',
#  '본사 부서 책임 회피',
#  '본사 응대 태도 문제',
#  '조직문화',
#  '책임감',
#  '업무 프로세스 이해',
#  '지점 책임',
#  '본사 내부통제 미흡',
#  '힘 있는 부서',
#  'KPI 검증',
#  '경영감사',
#  '내부통제 인식',
#  '전문성 부족 인사 이동',
#  '법인카드 사용 통제',
#  '단기 성과 중심 경력직 채용',
#  '부서 이동 문제',
#  '경영진 간섭 부족',
#  '업무처리 시스템',
#  '예외업무 매뉴얼',
#  '서류 보완',
#  '내부통제 인식',
#  '해외주식',
#  '단가 수작업',
#  '리스크',
#  '영업환경 어려움',
#  '신규고객',
#  '내부통제 인식',
#  '내부통제 절차',
#  '미비서류 보완',
#  '금융사고',
#  '내부통제 절차',
#  '점검',
#  '해외주식',
#  '매수단가',
#  '수작업',
#  '금융감독원 민원',
#  '결제라인',
#  '보고시스템',
#  '강화',
#  '금융상품',
#  '완전판매 절차',
#  '리스크',
#  '투자등급',
#  '주식 주문',
#  '해외 주식',
#  '부서장 전문성',
#  '공정한 인사발령',
#  '성과급제도',
#  'R&R',
#  '내부통제 교육',
#  '관리부서 오류',
#  'IT 인력 및 장비',
#  '본사 불신감',
#  '영업 순환 형평성',
#  'KPI 이슈',
#  '상품 판매 독려 과도',
#  'KPI',
#  '정책 변화',
#  '이슈 상품',
#  '해외주식',
#  '가이드 부족',
#  '고객 서비스',
#  '전자문서',
#  '연동 문제',
#  '종이문서',
#  '직원 마인드',
#  '안일한 태도',
#  '금융사고',
#  '내부통제',
#  '빡빡함',
#  '금융사고',
#  '조사',
#  '징계',
#  '내부통제 교육 부족',
#  '금전대차 위반 인식',
#  '서류 간소화',
#  'SMEET 녹취 에러',
#  '전산시스템 개선',
#  '법인선물옵션부 문제',
#  '내부통제 강화 필요',
#  '신용 대출',
#  '과도한 규제',
#  '리스크',
#  '업무 마감 시스템',
#  '개선 필요',
#  '증빙 자료',
#  '내부통제 규정',
#  '고객 중심',
#  '융통성',
#  '리테일',
#  '내부통제',
#  '시스템 부재',
#  '불명확성',
#  '신용 대출',
#  '규제',
#  '고객 이탈',
#  '단기 성과',
#  '인센티브 지급',
#  '내부통제',
#  '인사 문제',
#  '신용 대출',
#  '규제',
#  '과도',
#  '내부통제',
#  '제안서',
#  '활용 차단',
#  '대안',
#  '중복 감사',
#  '정신적 부담',
#  '정상 부서 감사',
#  '상품 판매',
#  '미비점',
#  '규정 준수',
#  '중요성 인식',
#  '업무 미루기',
#  '지연',
#  '고객 창구 대기',
#  '정부제도',
#  '그레이존',
#  '전산개발',
#  'GMS',
#  'IB',
#  '실적',
#  '수익',
#  '압박',
#  '조직문화',
#  '개선',
#  '내부통제',
#  '고객 주문',
#  '외부영업',
#  '대리주문',
#  '부적절한 관행',
#  '고객 신뢰',
#  '직원 사기',
#  '실적 압박',
#  '평가 시스템',
#  '금융상품',
#  '불완전 판매',
#  '위험',
#  '채권 고령자상품',
#  '숙려제도',
#  '수익금',
#  '상품경쟁력',
#  '투상부 적극성',
#  '금리 경쟁력',
#  '성과 부서',
#  '정밀 점검',
#  '사모상품',
#  '적극적 해결',
#  '승인 프로세스',
#  '시스템 개선',
#  '매뉴얼 등재',
#  '전자문서',
#  '결재 편의성',
#  '문서화',
#  '순환보직',
#  '장기근무',
#  '시스템 개선',
#  '매뉴얼 등재',
#  '해외주식 단가',
#  '골드넷+ 화면 업데이트',
#  '업무 변경 안내',
#  '매뉴얼 등재 누락',
#  '업무 매뉴얼',
#  '안내 일원화',
#  '업무 가이드',
#  '본사 직원 마인드 개선',
#  '업무 처리 개선',
#  '책임자 승인 프로세스',
#  '해외주식 단가 입력',
#  '매뉴얼',
#  '온라인 거래',
#  '고객 소통',
#  '상황 파악',
#  '업무능력 향상',
#  '순환보직',
#  '신용 대출',
#  '과도한 규제',
#  '벤치마킹',
#  '성과한도',
#  '운용한도',
#  '전직원 공유',
#  '시스템 공유',
#  '신용 대출',
#  '규제',
#  '리스크',
#  '영업직원',
#  '문자 발송',
#  '예시글 제공',
#  '표준화',
#  '지점 지원',
#  '내부통제',
#  '융통성',
#  '규정 강조',
#  '보신주의',
#  '융통성',
#  '주문 실수',
#  '상품 불완전 판매',
#  '리스크',
#  '형식적 관행',
#  '내부통제',
#  '개선 필요',
#  '대량 메일',
#  '승인 절차',
#  '불철저',
#  '과도한 자금 운용',
#  '고객 주문 대행',
#  '적절하지 않음',
#  '주문증빙',
#  '관리자 등록',
#  '시장 불확실성',
#  '선관의무 준수',
#  '이해상충',
#  '문제점',
#  '실행의지',
#  '승인 프로세스',
#  '단가 입력',
#  '전자직인 날인',
#  '화면 업데이트',
#  '법규 재개정',
#  '매뉴얼 부족',
#  '신용/대출 리스크',
#  '미수채권 회수',
#  '선물옵션 담당자',
#  '시스템적 통제',
#  '본사 마인드',
#  '순환보직 체계',
#  '승인 프로세스',
#  '해외주식',
#  '시스템 개선',
#  '골드넷+',
#  '업무 변경',
#  '매뉴얼 등재',
#  '업무 가이드',
#  '매뉴얼',
#  '일원화',
#  '문의 처리',
#  '본사 직원',
#  '마인드 개선',
#  '리스크 발생',
#  '주문증빙',
#  'SNS 이용',
#  '필수어 녹취',
#  '오류 발생',
#  '녹취 점검',
#  '골드넷+ 업무',
#  '형식적 점검',
#  '실질적 점검',
#  'KPI 목표',
#  '공정성 부족',
#  '영업과 수익 증가',
#  '과도한 내부통제',
#  '작은 실수',
#  '일 확대',
#  '내부통제',
#  '고객 불편',
#  '리스크 증가',
#  '내부통제 준수',
#  '직원 인식',
#  'CRM',
#  '관행적 절차',
#  'KPI 리스크',
#  '목표 유연성',
#  '온정주의',
#  '외부 인력 관리',
#  '문화 개선',
#  'CEO 소통',
#  '내부통제',
#  '규정 준수',
#  '직원 인식',
#  '업무 프로세스',
#  '고객 불편',
#  '녹취',
#  '고객 정보 전송',
#  '리스크',
#  '수동 처리',
#  'KPI',
#  '전략과제',
#  '리스크',
#  '전략방향',
#  '시장중심',
#  '고객중심',
#  'Smeet',
#  'KPI 재고',
#  '절차 간소화',
#  '영업직원 역량',
#  '교육 개선',
#  '증권사관학교',
#  '임원 균형',
#  '내부 전문가 육성',
#  '책임자 역할',
#  '내부통제',
#  '형식적',
#  '실적 우수자',
#  '내부통제',
#  '영업형 지점장',
#  '관리 영역',
#  '정책',
#  '포용',
#  'KPI',
#  '본사 분위기',
#  '내부통제',
#  '고객 불만',
#  '친밀감',
#  '실물이전 절차',
#  '시스템 개선',
#  '고객 불편',
#  '정보 소통',
#  '회사 분위기',
#  '회사 위상',
#  '금융상품',
#  '설계단계',
#  '녹음기능',
#  '수작업',
#  '이메일',
#  '사고',
#  '시스템화',
#  '엑셀',
#  '현장 관리',
#  '승인 프로세스',
#  '개선 필요',
#  '내부통제',
#  '미비 보완',
#  '해외주식 프로세스',
#  '데이터 정확도',
#  '전자문서 시스템',
#  '대주주 대출',
#  '시스템 구축',
#  '실무교육 부족',
#  'HTS 교육 필요',
#  'ODS 시스템 잡음',
#  '녹취 장비 교체',
#  '금융 사고',
#  '변화 없음',
#  '사기 저하',
#  '승인 프로세스',
#  '개선 필요',
#  '책임자 부재',
#  '미비사항',
#  '인식 개선',
#  '교육 필요',
#  '서류 스캔',
#  '불시 감사제도',
#  '시스템 개선',
#  '고객 안내',
#  '직원 공지',
#  '전자문서 고도화',
#  '승인 프로세스',
#  '데이터 정확성',
#  '리스크 노출',
#  ...]

# %%
import numpy as np
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.metrics import silhouette_score
from collections import defaultdict


# 모든 키워드를 하나의 리스트로 합칩니다.
keywords = []
# df_keyword['km_f'] = df_keyword['km_f'].apply(ast.literal_eval)
for row in df_keyword["km_f"]:
    for i in row:
        keywords.append(i)

# 중복 제거
keywords = list(set(keywords))
print(keywords)


# 2. 전처리 함수 정의
def preprocess(texts):
    okt = Okt()
    processed_texts = []
    for text in texts:
        # 형태소 분석 및 불용어 제거
        tokens = okt.nouns(text)
        processed_text = " ".join(tokens)
        processed_texts.append(processed_text)
    return processed_texts


processed_keywords = preprocess(keywords)

# 3. TF-IDF 벡터화
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(processed_keywords)

# 4. 최적의 클러스터 수 결정
from sklearn.metrics import silhouette_score

range_n_clusters = list(range(250, 251))  # 클러스터 수를 2에서 100까지 테스트
best_n_clusters = 0
best_silhouette_score = -1

for n_clusters in range_n_clusters:
    clustering = AgglomerativeClustering(n_clusters=n_clusters, linkage="average")
    labels = clustering.fit_predict(X.toarray())
    sil_score = silhouette_score(X.toarray(), labels, metric="cosine")
    print(f"클러스터 수: {n_clusters}, 실루엣 스코어: {sil_score:.4f}")
    if sil_score > best_silhouette_score:
        best_silhouette_score = sil_score
        best_n_clusters = n_clusters
        best_labels = labels

print(
    f"\n최적의 클러스터 수: {best_n_clusters}, 최고 실루엣 스코어: {best_silhouette_score:.4f}"
)

# 최적의 클러스터링 결과 사용
labels = best_labels

# 5. 결과 정리
cluster_dict = defaultdict(list)
for label, keyword in zip(labels, keywords):
    cluster_dict[label].append(keyword)

# 6. 대표 키워드 선정 (TF-IDF 가중치를 활용)
representative_keywords = {}
terms = vectorizer.get_feature_names_out()
for label in cluster_dict:
    cluster_indices = [i for i, l in enumerate(labels) if l == label]
    cluster_vectors = X[cluster_indices]
    # 클러스터 내 TF-IDF 가중치 합산
    tfidf_sum = cluster_vectors.sum(axis=0)
    tfidf_sum_array = np.asarray(tfidf_sum).flatten()
    # 가장 높은 TF-IDF 가중치를 가진 단어 선택
    top_index = tfidf_sum_array.argmax()
    representative_keyword = terms[top_index]
    representative_keywords[label] = representative_keyword

# 7. 결과 출력
for label, keyword_list in cluster_dict.items():
    print(f"\n클러스터 {label + 1}: 대표 키워드 - {representative_keywords[label]}")
    print("키워드들:")
    for keyword in keyword_list:
        print(f"- {keyword}")
# Out:
# ['시스템 개선', '영업과 수익 증가', '규정 확인', '녹취 장비', '관리자 제도 폐쇄', '면담 불필요', '작은 실수', '프로세스 재정비', '인원 확충', '사규 재개정', '직원 리드', '징계 조치', '신용 등급', '온라인가입', '상품 가입 미비', '업무 문의', '해외주식 평가액', '전략과제', '고객응대', '면담 프로세스', '융통성 처리', '프로세스 세부 검토', '법카 지원 불공평', '책임자 역할', '시뮬레이션 화면', '과도한 목표', '주문 실수', '직원 사기', '조사', '고객 이탈', '영업전환', 'IT 문제', '주문시스템', '영업직원', '신용만기 안내 누락', '업무 세분화', '업무 프로세스 개선', '차등 적용', '고객지원센터', '실행의지', '시스템 사용 부족', '영업지원비', 'S-MEET 시스템', '외부사 협업 기피', '단기 성과', '임피직원 문제', '교육자료', '명부 오류', '직원 인성 확인', '수기잔액증명서', '인수인계서', '인력배치', '선물옵션', '골드넷+ 업무', '사고예방', '업무처리', '영업 직무', '메신저 기록', '투상 인력', '상품 판매', '법선 수익부서 제외', '금융투자상품', '자동 번역', '목표 배정 프로세스', '효율성', '책임자 처벌', '해외주식 주문', '자발적 야근', '사고 사례', '채권부 수익구조', '과도한 규제', '책임 명문화', '윤리준수 교육', '법인영업 위축', '사건사고', '수직적 조직문화', '서류 문제', '리테일 위기', '적절하지 않음', '우선순위 처리', '자동 연장 필요', '영업직원 역량', '내부통제 장기 미비', '과도한 KPI', '본사부서 역할', 'YES맨 문화', '리스크 노출', '내부통제', '대출 기준', '확인 절차', '상품 분쟁 예방', '업무팀', '종이서류', '완전판매 확인', '지점 축소', '불철저', '불확실성', '녹취 중복', '인력배치 문제', '경영감사', '통제 불합리', '상품제안서 제약', '운용한도', '정신적 부담', '불만', '전산 프로그램', '사건내용 안내', '계좌 개설', '업무 미루기', '경영진 간섭 부족', '리스크 제거', '담당자 찾기', '목표 과중', '입력 이슈', '고객신뢰 하락', '녹취 점검', '문서 스캔', '해외주식 입력 프로세스', '미비한 업무절차', '문자 발송', '서류 스캔', '무리한 영업', '팀제 필요', '외부조사', '체계적인 확립', 'OTC 거래', '경력직원 검증', '경쟁력 데이터', '경위서 제출 요구', '내부통제 문제', '순환보직', '녹취 장비 문제', '내부통제 허술', '위축', '담당자 찾기 어려움', '리스크 상품', '녹록한 대응', 'BEP 차등 부여', '부점 직원 자질', '업무시스템', '수익 손실', '성과수수료', '서류 간소화', '강력한 처벌', '철저한 감사', '주니어 기회', '매매 체크', '업무 퀄리티', '부서간 협력', '주문증빙', '직원 불만', '영향도 큼', '모호성', '자료 발송 시스템', '업무 프로세스', '전문팀 통합', '수익구조 개선', '내부통제 필요', '통제 부족', '리스크 확인 필요', '라임사태', '고객 서비스', '교육 접근성', '결제라인', '비밀번호 입력', '대주주 대출', '불완전 판매', '장기근속자', '직원 인식', '직무전환', '책임 의식 부족', '업무 시스템', '인적 문제', '고스트PC', '유선업무', '관리와 영업 분리', '선관의무 준수', '대면 녹취', '중징계', '실적 압박', '본사 검증', '부서별 협업', '전문 인력 부재', '해외주식 시스템 개선', '출금 방법 개선', '자동발송', '내부통제 수준', '교육 필요', '전략 부재', '시스템 예방', '보완', '대출', '타사 시스템 차이', '성과 부서', '조직문화 개선', '투자 권유 가이드라인', '해외주식 자료 부족', '매수단가', '관리 영역', '수익부서 직원 관리', '부서 이동 문제', '불합리한 인사', '리소스 부족', '직원 희생', '민원 발생', '성과급제도', 'Account Risk', '본사부서', '전략방향', '이자 산정', '시스템 사용 어려움', '직원 발전', '안전상품', '본사 직원', '시니어', '인사 문제', '게시물 필요', '내부통제 강화 필요', '고객 자금 횡령', '수익', '해외주식 프로세스', '성과급체계', '과도한 통제', '지점 책임', '온라인 거래', '계약 과정', '사용율 낮음', '역할 명확화', '시스템적 통제', 'E-mail 프로세스', '개선', '내부통제 인식', '동기부여 부족', '연금 해지 계좌', '책임 환경', '서류 미비', '파워 집중', '고객지원팀장', '무담보 미수채권 관리', '오류 발생', '팀 인센티브 제도', '비관리계좌', '상황 파악', '미래에셋증권', '문의부재', '외부 인력 관리', '주문실수', '고객중심', 'PB 권한', '불편함', '공지 필요', '주문 관행', '비밀번호 없이 전환', '인식 수준', '큰 금액 처리', '시스템 부재', '사고 위험성', '전자화문서 시스템', '업무 어려움', 'IT 인력 및 장비', '인사부', '인계인수', '여신대출', '순환보직 제도', '조직적 문제', '관련 내용 공지', '민원', '법인선물옵션부 문제', '인사배치', '해외주식 시스템', '대직자 부재', '대출 기준 축소', '법무실', '영업 유혹', '시뮬레이션 개선', '공정한 인사발령', '예외연장 기준', '시스템 작동 불가', '신용/대출 통제', '수기 업무', '정부제도', '해외주식 입력', '관계 확인', '상급자 지시 문제', '주기적 보고', '업무 지원 필요', '과도한 내부통제', '인적 쇄신', '시스템 교육', '현장 경험', '평판 리스크 하락', '일시적 중단', '저하', '업무 교육', '부서명 변경', '업무능력 향상', '개인 역량', '투명한 공개', '매뉴얼 부족', '업무량 증가', '중요성 인식', '명확한 해석', '영업사원', '주식 차입', '인당 노력', '장기근무', '업무 시스템 개선', '매수가격', '오프라인 매매', '본사 부서 업무 중단', '내부 통제', '업무집중화팀', '내부통제 과다', '최종 결론 공개', '서류간소화', '부적절한 경향', '상품 검증', '팀장 부재', '회수불가', '질권 업무', '고객 제안 제약', '세대 간 소통', '경영진 변화 필요', '전문가 배치', '메신저 처리 관행', '경력 부족', '부서 세분화', '더블카운팅', '본사직원', '운영리스크', '해외주식 단가변경', '금융감독원 민원', '금융 사고', '시니어부족', '크로스 체크', '오프라인 고객', '시스템 문제', 'KPI 리스크', '점검', '형식적 관행', 'LP업무', '영업과 본사 간 괴리', '위험', '전반적 재검토', '법인카드', 'CEO 소통', '상품 가입 절차 문제', 'KPI 감점 가능성', '전수조사', '세금 관련 입금', '대비', '공모주 업무', '업무 지원 부족', '법인 인감', '수동 처리', '내부통제 교육', '한도', '직원 마인드', '선물옵션 담당자', '지점 운영', '금융상품 경쟁력', '법인카드 리스크', '시스템 개발', '제도적 변화', '업무량 차이', '징계 수위', '시간 소요', '업무 변경 안내', '고객 자산', '내부통제 권한 부족', '고객 정보 전송', '계열사 업무', '상담일지', '접근 불가', '권한 집중', '금융상품 채권', '내부통제 준수', '처리 지연', '발령 혜택', '인센티브', '규제', '쪽지 전달방식', '파견인원 부족', '친밀감', '부서간 크로스체크', '일 확대', '인센티브 구조 문제', '디지털창구', '대출 등급', '상품판매 리스크', '전자화 시스템', '서류 완화', '난국', '사고상품 관리', '시스템 개선 필요', '채권금리', '필수어 녹취' ...
# 클러스터 수: 250, 실루엣 스코어: 0.2235
#
# 최적의 클러스터 수: 250, 최고 실루엣 스코어: 0.2235
#
# 클러스터 10: 대표 키워드 - 직원
# 키워드들:
# - 시스템 개선
# - 직원 리드
# - 고객응대
# - 직원 사기
# - 실행의지
# - 임피직원 문제
# - 직원 인성 확인
# - 적절하지 않음
# - 불만
# - 경력직원 검증
# - 부점 직원 자질
# - 직원 불만
# - 교육 접근성
# - 직원 인식
# - 출금 방법 개선
# - 내부통제 수준
# - 교육 필요
# - 직원 희생
# - Account Risk
# - 직원 발전
# - 본사 직원
# - 개선
# - 내부통제 인식
# - 불편함
# - 공지 필요
# - 인식 수준
# - 관련 내용 공지
# - 시스템 교육
# - 업무 교육
# - 중요성 인식
# - 업무 시스템 개선
# - 경력 부족
# - 본사직원
# - 내부통제 교육
# - 직원 마인드
# - 시스템 개선 필요
# - 직원 공지
# - 높은 KPI
# - 직원 인식 부족
# - HTS 교육 필요
# - 직원
# - 직원 실망감 해소
# - 본사 마인드
# - 교육 개선
# - 로열티
# - 개선 필요 없음
# - 절차 개선
# - KPI
# - 인식 개선
# - 교육 필요성
# - 응대 직원 부족
# - 내부통제 중요성 인식
# - HTS
# - 직원 교육
# - 본사 직원 마인드 개선
# - 업무 개선 건의
# - 완벽하지 않음
# - IRP
# - 업무 개선
# - 프론트직원
# - 업무공지
# - 신분증
# - 내부통제 교육 부족
# - PB 인식
# - PB 교육
# - 업무 공유
# - ELB
# - 개선 필요
# - PB
# - MTS
# - 시스템 불만
# - 직원의 태도 불만
# - 실무교육 부족
# - 마인드 개선
# - Smeet
# - 교육
# - 내부통제 중요성
# - 안일한 태도
# - PWM
# - 절차 개선 필요
# - 신분증 인식
# - 비관리계좌 고객 응대
# - 경력직
# - R&R
# - 미비함
# - CRM
# - 직원 로열티 부족
# - 공지 부족
# - IB
# - 시스템 공유
# - 금전대차 위반 인식
# - 직원의지
# - 전직원 공유
# - 고객 응대
# - GMS
# - 고객 불만
# - 본사 응대 태도 문제
# - 본사 불신감
# - 인식부족
#
# 클러스터 16: 대표 키워드 - 증가
# 키워드들:
# - 영업과 수익 증가
# - 업무량 증가
# - 업무량 차이
# - 인원 증가
# - 리스크 증가
# - 감사 횟수 증가
# - 업무량 과다
#
# 클러스터 105: 대표 키워드 - 규정
# 키워드들:
# - 규정 확인
# - 내부통제 규정
# - 규정 반영
# - 영업강조
# - 규정 강조
#
# 클러스터 19: 대표 키워드 - 녹취
# 키워드들:
# - 녹취 장비
# - 녹취 장비 문제
# - 유선업무
# - 대면 녹취
# - IT 인력 및 장비
# - 필수어 녹취
# - 대면 녹취 점검
# - 녹취 시스템
# - 녹취장비
# - 대면녹취
# - 녹취시스템 간소화
# - SMEET 녹취 에러
# - 녹취 장비 교체
# - 전화녹취 개선
# - 유선 녹취 없음
# - 녹취
#
# 클러스터 61: 대표 키워드 - 관리자
# 키워드들:
# - 관리자 제도 폐쇄
# - 관리자 제도 폐지
# - 관리자 등록
# - 상품별 관리자
# - 랩 관리자 변경
#
# 클러스터 30: 대표 키워드 - 프로세스
# 키워드들:
# - 면담 불필요
# - 면담 프로세스
# - 업무 프로세스 개선
# - 업무 프로세스
# - E-mail 프로세스
# - 판매 프로세스
# - 환전우대
# - 환전 프로세스
# - 상식적인 프로세스
# - 프로세스 개선
#
# 클러스터 70: 대표 키워드 - 주문
# 키워드들:
# - 작은 실수
# - 주문 실수
# - 주문증빙
# - 주문실수
# - 고객 주문 대행
# - 증빙 없는 주문
# - 대리주문
# - 전화주문 증빙
# - 고객 주문
# - 전화 대리
#
# 클러스터 28: 대표 키워드 - 내부통제
# 키워드들:
# - 프로세스 재정비
# - 내부통제
# - 내부통제 문제
# - 내부통제 허술
# - 내부통제 필요
# - 내부통제 강화 필요
# - 내부통제 과다
# - 강화
# - 내부통제 제약
# - 내부통제 재정립
# - 내부통제 강화
# - 시스템 강화
# - 내부통제 강도
# - 자질 강화
# - 내부통제 재정비
# - 제도 재정비
#
# 클러스터 42: 대표 키워드 - 인원
# 키워드들:
# - 인원 확충
# - 파견인원 부족
# - 파견 인원
# - 확충 필요
#
# 클러스터 139: 대표 키워드 - 재개
# 키워드들:
# - 사규 재개정
# - 법규 재개정
#
# 클러스터 179: 대표 키워드 - 징계
# 키워드들:
# - 징계 조치
# - 중징계
# - 징계 수위
# - 평가와 징계
# - 징계
#
# 클러스터 8: 대표 키워드 - 대출
# 키워드들:
# - 신용 등급
# - 대출 기준
# - 대주주 대출
# - 대출
# - 여신대출
# - 대출 기준 축소
# - 신용/대출 통제
# - 대출 등급
# - 대주주 대출 시스템
# - 신용 업무
# - 신용 대출
# - 투자등급
# - 대출 자금
# - 신용대출
# - 신용/대출 시뮬레이션
# - 리츠 대출 문제
# - 신용/대출 리스크
# - 신용/대출 처리 기준
# - 등급 변경
# - 대주주 대출업무
#
# 클러스터 11: 대표 키워드 - 고객
# 키워드들:
# - 온라인가입
# - 고객 이탈
# - 고객 자금 횡령
# - 고객지원팀장
# - 고객 정보 전송
# - 고객 입금
# - 온라인 고객
# - 고객 동의 없는 등록
# - 모바일 고객
# - 고객 이탈 가능성
# - 고객 안내
# - 고객 정보 갱신
# - 고객동의 절차
#
# 클러스터 26: 대표 키워드 - 상품
# 키워드들:
# - 상품 가입 미비
# - 금융투자상품
# - 경쟁력 데이터
# - 안전상품
# - 금융상품 경쟁력
# - 금융상품 채권
# - 금융상품 가입
# - 경쟁력 없는 상품
# - 채권상품부
# - 금융상품 절차 부족
# - 상품 가입 보완 부족
# - 경쟁력
# - 기업금융
# - 상품경쟁력
# - 금융상품 녹취
# - 채권 커뮤니케이션
# - 상품 선가입
# - 중장기성 상품
# - 금융상품 서류
# - 채권상품
# - 채권 고령자상품
# - 채권 매도
# - 금융상품 공부
# - 금융상품
# - 상품 선가입 미비
# - 채권잔고
#
# 클러스터 197: 대표 키워드 - 문의
# 키워드들:
# - 업무 문의
# - 문의부재
# - 문의 처리
# - 문의
# - 업무문의
# - 고객 문의
# - 문의 필요
#
# 클러스터 215: 대표 키워드 - 주식
# 키워드들:
# - 해외주식 평가액
# - 해외주식 주문
# - 해외주식 입력 프로세스
# - 해외주식 시스템 개선
# - 해외주식 자료 부족
# - 해외주식 프로세스
# - 해외주식 시스템
# - 해외주식 입력
# - 주식 차입
# - 해외주식 단가변경
# - 해외주식양도세
# - 해외주식 정보력
# - 주식
# - 해외 주식
# - 국내주식
# - 해외주식 프로그램
# - 국내주식 약세장
# - 해외주식 거래
# - 해외주식 단가
# - 주식 주문
# - 주식영업
# - 해외주식 단가입력
# - 해외주식 단가 입력
# - 해외주식
# - 해외주식 이관
#
# 클러스터 127: 대표 키워드 - 전략
# 키워드들:
# - 전략과제
# - 전략 부재
# - 전략방향
# - 전략과제 문제
# - 전략과제 조정
# - 전략과제 관리
# - 상품 전략
#
# 클러스터 81: 대표 키워드 - 융통성
# 키워드들:
# - 융통성 처리
# - 융통성 부족
# - 융통성 결여
# - 융통성
#
# 클러스터 97: 대표 키워드 - 검토
# 키워드들:
# - 프로세스 세부 검토
# - 전반적 재검토
# - 상품검토
#
# 클러스터 50: 대표 키워드 - 지원
# 키워드들:
# - 법카 지원 불공평
# - 고객지원센터
# - 영업지원비
# - 업무 지원 필요
# - 업무 지원 부족
# - 센터장
# - 영업지원
# - 지점 지원
# - 본사 지원
#
# 클러스터 46: 대표 키워드 - 역할
# 키워드들:
# - 책임자 역할
# - 역할 명확화
# - R&R 명확화
# - 관리자 감독 역할
#
# 클러스터 86: 대표 키워드 - 데이터
# 키워드들:
# - 시뮬레이션 화면
# - 시뮬레이션 개선
# - 데이터 정확성
# - 시뮬레이션 데이터
# - 데이터 개선
# - 데이터 정확도
#
# 클러스터 1: 대표 키워드 - 과도
# 키워드들:
# - 과도한 목표
# - 목표 배정 프로세스
# - 과도한 규제
# - 과도한 KPI
# - 목표 과중
# - 과도한 통제
# - 과도한 내부통제
# - 규제
# - 과도한 자금 운용
# - KPI 목표 배정
# - 과도
# - 업무 과중
# - KPI 과도한 목표
# - 목표 유연성
# - 과도한 감사
# - KPI 목표
#
# 클러스터 27: 대표 키워드 - 외부
# 키워드들:
# - 조사
# - 외부조사
# - 전수조사
# - 외부영업
# - 외부 활동 직원 지원 부족
# - 외부활동 위축
# - 외부인사 영입
# - 외부활동
#
# 클러스터 14: 대표 키워드 - 영업
# 키워드들:
# - 영업전환
# - 영업 직무
# - 법인영업 위축
# - 우선순위 처리
# - 무리한 영업
# - 위축
# - 직무전환
# - 영업 유혹
# - 영업사원
# - 영업과 본사 간 괴리
# - 채권영업
# - 영업 방향성
# - 법인영업
# - 영업 우선
# - 영업
# - 영업 직무 전환
# - 영업 위축
# - 대외영업
# - 법인영업 타격
# - 안전한 영업
# - 법인영업센터
# - IB연계 영업
# - KPI 방향성
# - 영업추진부
# - 직무 순환
# - 개인적 영업 타격
# - 파생영업 부서
# - 영업 전환
# - 계좌 전환
# - IB영업
# - 영업 지양
#
# 클러스터 5: 대표 키워드 - 문제
# 키워드들:
# - IT 문제
# - 채권부 수익구조
# - 수익구조 개선
# - 시스템 문제
# - 인센티브 구조 문제
# - 잡음 문제
# - 문제 방지
# - 문제 재발 방지
# - 소음 문제
# - 구조적 문제
# - 지점 구조
# - KPI 문제
# - 주변소음
# - 고객 유도 문제
# - psr 허들 문제
# - 조직적 구조 문제
# - 인력 문제
# - 상품 문제
# - ODS 시스템 잡음
#
# 클러스터 15: 대표 키워드 - 시스템
# 키워드들:
# - 주문시스템
# - S-MEET 시스템
# - 전산 프로그램
# - 업무시스템
# - 업무 시스템
# - 시스템 작동 불가
# - 시스템 개발
# - 시스템화
# - ODS시스템
# - 전산화
# - 시스템
# - 시스템 헛점
# - AI 시스템
# - 전산시스템 불안정
# - ODS 시스템
# - 전산시스템 개선
# - 전산개발
# - 업무 마감 시스템
# - 체크리스트 전산화
# - 팝업 시스템
# - 시스템 개발 필요
# - 평가 시스템
#
# 클러스터 18: 대표 키워드 - 신뢰
# 키워드들:
# - 영업직원
# - 영업직원 역량
# - 고객신뢰 하락
# - 영업직원 신뢰
# - 신뢰 감소
# - 고객 신뢰
# - 심사 신뢰 부족
#
# 클러스터 45: 대표 키워드 - 누락
# 키워드들:
# - 신용만기 안내 누락
# - 권리 누락
# - 신고 누락 리스크
# - 만기 누락
# - 대출 만기 연장
#
# 클러스터 187: 대표 키워드 - 세분
# 키워드들:
# - 업무 세분화
# - 부서 세분화
# - 업무메뉴얼 세분화
# - KPI 세분화
# - 조직 세분화
#
# 클러스터 24: 대표 키워드 - 적용
# 키워드들:
# - 차등 적용
# - BEP 차등 부여
# - 동일 적용
# - 일률적인 절차 적용
#
# 클러스터 48: 대표 키워드 - 사용
# 키워드들:
# - 시스템 사용 부족
# - 시스템 사용 어려움
# - 사용율 낮음
# - MTS 사용 불편
# - 고객 불편
# - 사용할당 과다
# - 회사북 사용
#
# 클러스터 40: 대표 키워드 - 협업
# 키워드들:
# - 외부사 협업 기피
# - 부서별 협업
# - 그룹 협업 부족
# - 협업
# - 협업 강화
# - 협업 문제
#
# 클러스터 103: 대표 키워드 - 성과
# 키워드들:
# - 단기 성과
# - 성과 부서
# - 성과 보상
# - 단기성과 정책
# - 단기성과
# - 영업성과
# - 단기 성과 중심 경력직 채용
# - 조직성과
# - 탐욕과 단기성과주의
# - 단기 성과주의
#
# 클러스터 155: 대표 키워드 - 자료
# 키워드들:
# - 교육자료
# - 자료 발송 시스템
# - 증빙 자료
# - 자료
# - 보고자료 과다 요청
#
# 클러스터 223: 대표 키워드 - 오류
# 키워드들:
# - 명부 오류
# - 오류 발생
# - 관리부서 오류
# - 세액 공제 오류
# - 데이터 오류
# - 폰패드 오류
# - 오류
#
# 클러스터 200: 대표 키워드 - 잔액
# 키워드들:
# - 수기잔액증명서
#
# 클러스터 3: 대표 키워드 - 인계
# 키워드들:
# - 인수인계서
# - 인계인수
# - 일 확대
# - 인수인계 관리
# - 인수인계
# - 인수인계서 확대
#
# 클러스터 13: 대표 키워드 - 인력
# 키워드들:
# - 인력배치
# - 투상 인력
# - 인력배치 문제
# - 외부 인력 관리
# - 인사배치
# - 투상 인력 과다
# - 젊은 인력 구성
# - 인적 구성
# - 인사 부서배치
# - 인사 인력배치
# - 인력 개선
# - 인력관리 개선
# - 인력 배치
# - 인사 재구성
#
# 클러스터 78: 대표 키워드 - 선물옵션
# 키워드들:
# - 선물옵션
# - 법인선물옵션부 문제
# - 선물옵션 담당자
# - 법인선물옵션부 퇴사
# - 선물옵션 전문가
#
# 클러스터 95: 대표 키워드 - 골드
# 키워드들:
# - 골드넷+ 업무
# - 골드넷 승인
# - 골드넷+
# - 골드넷+ 교육
#
# 클러스터 49: 대표 키워드 - 예방
# 키워드들:
# - 사고예방
# - 상품 분쟁 예방
# - 시스템 예방
# - 고객 분쟁
#
# 클러스터 52: 대표 키워드 - 업무
# 키워드들:
# - 업무처리
# - 업무팀
# - 업무 미루기
# - 업무 퀄리티
# - 수기 업무
# - 부서명 변경
# - 질권 업무
# - LP업무
# - 공모주 업무
# - 업무 변경 안내
# - 업무범위
# - 업무처리자
# - 부적절한 업무
# - 업무담당자 변경
# - 업무 처리 개선
# - 업무 배분
# - 업무 변경
# - 업무처리 시스템
# - 내방 업무
# - 수기 처리 업무
# - 수기업무 위험
# - 업무 구분
# - 수기 처리
# - 업무적정
# - 선진행 업무
# - 업무과실
# - 수기처리 업무
# - 업무개발자
# - KPI 변경
#
# 클러스터 164: 대표 키워드 - 기록
# 키워드들:
# - 메신저 기록
#
# 클러스터 57: 대표 키워드 - 판매
# 키워드들:
# - 상품 판매
# - 완전판매 확인
# - 불완전 판매
# - 상품판매 리스크
# - 판매 금지
# - 상품 판매 독려 과도
# - 상품 판매 신뢰
# - 상품 불완전 판매
# - 완전판매 절차
#
# 클러스터 43: 대표 키워드 - 부서
# 키워드들:
# - 법선 수익부서 제외
# - 본사부서 역할
# - 부서간 협력
# - 수익부서 직원 관리
# - 본사부서
# - 수익
# - 본사 부서 업무 중단
# - 본사 부서 갑질
# - 본사 부서 불통
# - 본사 결제부서 인원 충원
# - 부서와의 합의
# - 상품부서
# - 본사부서 전문성
# - KPI 제외
# - 수익율 리스크
# - 수익부서
# - 본사부서 느슨한 내부통제
# - 힘 있는 부서
# - 부서
# - 부서수익
# - 수익부서 지정 문제
#
# 클러스터 34: 대표 키워드 - 자동
# 키워드들:
# - 자동 번역
# - 자동 연장 필요
# - 문자 발송
# - 자동발송
# - 자동이체 환불
#
# 클러스터 59: 대표 키워드 - 지점
# 키워드들:
# - 효율성
# - 지점 축소
# - 지점 내부통제
# - 보라매지점 흡수
# - 지점 담당자 비효율
# - 영업형 지점장
#
# 클러스터 229: 대표 키워드 - 처벌
# 키워드들:
# - 책임자 처벌
# - 강력한 처벌
# - 솜방망이 처벌
#
# 클러스터 178: 대표 키워드 - 야근
# 키워드들:
# - 자발적 야근
#
# 클러스터 6: 대표 키워드 - 사례
# 키워드들:
# - 사고 사례
# - 재무관리부 안내
# - 사례 안내
# - 사례중심교육
#
# 클러스터 32: 대표 키워드 - 책임
# 키워드들:
# - 책임 명문화
# - 책임 의식 부족
# - 지점 책임
# - 책임 환경
# - 책임 회피 응대
# - 본사 부서 책임 회피
# - 책임 회피
# - 책임
# - 기획자 책임
# - 업무 환경
# - 책임소재 불분명
# - 영업 책임
#
# 클러스터 56: 대표 키워드 - 준수
# 키워드들:
# - 윤리준수 교육
# - 선관의무 준수
# - 내부통제 준수
# - 규정 준수
# - 법규준수
#
# 클러스터 247: 대표 키워드 - 사건
# 키워드들:
# - 사건사고
# - 사건내용 안내
# - 사건 반복
#
# 클러스터 4: 대표 키워드 - 조직
# 키워드들:
# - 수직적 조직문화
# - YES맨 문화
# - 관리와 영업 분리
# - 조직문화 개선
# - 조직적 문제
# - 법인전담팀 필요
# - 조직 시스템
# - 조직 개선
# - 전담 조직
# - 조직변경 문제
# - 조직 분리
# - 조직 편성 변경
# - 조직문화
# - 회의감
# - 조직도 개편
# - 조직 슬림화
# - 조직 모니터링
# - 회의 문화
# - 문화 개선
#
# 클러스터 106: 대표 키워드 - 서류
# 키워드들:
# - 서류 문제
# - 서류 간소화
# - 서류간소화
# - 서류 완화
# - 결제 간소화
# - 가입 서류
# - 상품서류 간소화
# - 절차 간소화
# - 가입서류 보관
# - 서류 복잡성
# - 서류 과다
#
# 클러스터 33: 대표 키워드 - 이동
# 키워드들:
# - 리테일 위기
# - 부서 이동 문제
# - 리테일 이동
# - PWM 이동
# - 주기적 인사이동
# - 고객 이동
# - 리테일
#
# 클러스터 58: 대표 키워드 - 장기
# 키워드들:
# - 내부통제 장기 미비
# - 장기근속자
# - 장기근무
# - 롱텀 근무
# - 장기근속
#
# 클러스터 2: 대표 키워드 - 노출
# 키워드들:
# - 리스크 노출
# - 개인정보 보호
# - 개인정보 노출
# - 고객정보
# - 고객정보 노출
#
# 클러스터 110: 대표 키워드 - 절차
# 키워드들:
# - 확인 절차
# - 미비한 업무절차
# - 상품 가입 절차 문제
# - 내부통제 절차
# - 부적절한 업무절차
# - 부적절한 절차
# - 실물이전 절차
# - 절차 문제
# - 부적절한 업무 절차
#
# 클러스터 66: 대표 키워드 - 문서
# 키워드들:
# - 종이서류
# - 문서 스캔
# - 서류 스캔
# - 전자화문서 시스템
# - 전자화 시스템
# - 종이서류 전자화
# - 종이문서 전자화
# - 문서 스캔 기준
# - 문서화
# - 문서 다양성
# - 종이문서
# - 전자화문서
#
# 클러스터 176: 대표 키워드 - 철저
# 키워드들:
# - 불철저
#
# 클러스터 17: 대표 키워드 - 기준
# 키워드들:
# - 불확실성
# - 기준 불확실
# - 명확한 기준 필요
# - 시장 불확실성
# - 기준 불투명
# - 녹취 기준
# - 손익 소급 기준
#
# 클러스터 9: 대표 키워드 - 감사
# 키워드들:
# - 녹취 중복
# - 경영감사
# - 철저한 감사
# - 서류 중복
# - 총체적 감사 필요
# - 지점 감사
# - 중복 감사
# - 불시 감사제도
# - 정상 부서 감사
#
# 클러스터 38: 대표 키워드 - 인사
# 키워드들:
# - 통제 불합리
# - 불합리한 인사
# - 인사 문제
# - 인사부
# - 공정한 인사발령
# - 발령 혜택
# - 부서 발령
# - 인사 불합리
# - 인사 제도
# - 불합리한 관행
# - 인사관리
# - 인사발령
# - 인사 시스템
#
# 클러스터 73: 대표 키워드 - 제안
# 키워드들:
# - 상품제안서 제약
# - 고객 제안 제약
# - 개선 제안
# - 제안서
#
# 클러스터 37: 대표 키워드 - 한도
# 키워드들:
# - 운용한도
# - 한도
# - 한도 부여자
# - 한도 제한
# - 한도 초과
# - KPI 설정
# - 성과한도
# - 한도 설정
#
# 클러스터 90: 대표 키워드 - 부담
# 키워드들:
# - 정신적 부담
# - 심적 부담
# - 업무 부담
#
# 클러스터 29: 대표 키워드 - 관리
# 키워드들:
# - 계좌 개설
# - 관리 영역
# - 비관리계좌
# - 현장 경험
# - 법인계좌
# - 고객관리 연속성
# - 게시판 관리
# - 현장 관리
# - 계좌개설
# - 비관리 계좌
# - 법인계좌 정보 개선
# - 고객관리
# - 관리 계좌
# - 시재관리
# - 관리
# - 계좌 관리 리스크
# - 계좌정보
# - 고객 관리
#
# 클러스터 23: 대표 키워드 - 부족
# 키워드들:
# - 경영진 간섭 부족
# - 리소스 부족
# - 사전적 검열 부족
# - 책임지는 자세 부족
# - 공정성 부족
#
# 클러스터 62: 대표 키워드 - 리스크
# 키워드들:
# - 리스크 제거
# - 리스크 상품
# - 리스크 확인 필요
# - 평판 리스크 하락
# - KPI 리스크
# - 리스크 요인
# - 리스크 확인
# - 시장 리스크 관리
# - 리스크 분석
# - 평판리스크
# - 리스크
# - 리스크 관리
# - 포기 요인
# - 본사 리스크
# - 평판 리스크
# - 양도세 리스크
# - 평판 개선
#
# 클러스터 87: 대표 키워드 - 담당자
# 키워드들:
# - 담당자 찾기
# - 담당자 찾기 어려움
# - 담당자 관리
# - 매뉴얼 최신화
# - 본사 담당자 부재
# - 담당자 최신화
#
# 클러스터 101: 대표 키워드 - 이슈
# 키워드들:
# - 입력 이슈
# - 이슈 사모상품
# - 법률 이슈
# - 이슈 상품
# - KPI 이슈
# - 컴플이슈
# - 사모상품
#
# 클러스터 47: 대표 키워드 - 점검
# 키워드들:
# - 녹취 점검
# - 점검
# - 철저한 점검
# - 프로세스 점검
# - 자금 사용 점검
# - 정밀 점검
# - 정기적 감사
# - 실질적 점검
# - 정기적 점검
#
# 클러스터 55: 대표 키워드 - 전문
# 키워드들:
# - 팀제 필요
# - 전문팀 통합
# - 전문 인력 부재
# - 전문팀제 필요
# - 전문팀 필요
# - 전문 지식
# - 전문 인력 부족
#
# 클러스터 31: 대표 키워드 - 체계
# 키워드들:
# - 체계적인 확립
# - 성과급체계
# - 주기적 보고
# - 보고시스템
# - 관리체계
# - 대직체계
# - 보고체계
# - STR 보고작성 어려움
#
# 클러스터 227: 대표 키워드 - 거래
# 키워드들:
# - OTC 거래
# - 온라인 거래
# - 거래 가능액 감소
# - 채권거래 내역 불일치
# - Back-to-Back 거래
#
# 클러스터 77: 대표 키워드 - 요구
# 키워드들:
# - 경위서 제출 요구
# - 조치 요구
#
# 클러스터 21: 대표 키워드 - 순환
# 키워드들:
# - 순환보직
# - 순환보직 제도
# - 형평성 문제
# - 영업 순환 형평성
# - 순환보직 체계
#
# 클러스터 246: 대표 키워드 - 대응
# 키워드들:
# - 녹록한 대응
# - 대응 시나리오
# - 본사 대응
#
# 클러스터 92: 대표 키워드 - 손실
# 키워드들:
# - 수익 손실
# - 손실
#
# 클러스터 113: 대표 키워드 - 수수료
# 키워드들:
# - 성과수수료
# - 교섭수수료 누락
# - 수수료 경쟁력 문제
# - 수수료 확인
#
# 클러스터 163: 대표 키워드 - 주니어
# 키워드들:
# - 주니어 기회
# - 주니어 충원
#
# 클러스터 44: 대표 키워드 - 체크
# 키워드들:
# - 매매 체크
# - 크로스 체크
# - 부서간 크로스체크
# - 크로스체크
# - 크로스체크 필요
# - 결제내역 크로스체크
# - 체크 누락
# - 체크
#
# 클러스터 174: 대표 키워드 - 영향
# 키워드들:
# - 영향도 큼
#
# 클러스터 172: 대표 키워드 - 호성
# 키워드들:
# - 모호성
#
# 클러스터 71: 대표 키워드 - 통제
# 키워드들:
# - 통제 부족
# - 시스템적 통제
# - 내부 통제
# - 내부 통제 점검
# - 내부 전문가 육성
# - 내부 직원 육성
# - 준법 통제
# - 과한 통제
# - 내부 문제
# - 내부 통제 부족
# - 내부 인재 중용
# - 본사 내부 통제 사고
# - 통제
# - 파생상품 통제
# - 통제 시스템
# - 재무회계 통제
# - 통제 확인 시스템
# - 본사 통제 소홀
#
# 클러스터 93: 대표 키워드 - 라임
# 키워드들:
# - 라임사태
# - 현 사태
# - 라임
#
# 클러스터 124: 대표 키워드 - 서비스
# 키워드들:
# - 고객 서비스
# - 환율우대 서비스
#
# 클러스터 118: 대표 키워드 - 라인
# 키워드들:
# - 결제라인
# - 인사라인 부작용
#
# 클러스터 104: 대표 키워드 - 비밀번호
# 키워드들:
# - 비밀번호 입력
# - 비밀번호 없이 전환
# - 대표비밀번호
#
# 클러스터 75: 대표 키워드 - 인적
# 키워드들:
# - 인적 문제
# - 인적 쇄신
# - 인적쇄신
# - 이미지 쇄신
# - 인적쇄신 필요
#
# 클러스터 170: 대표 키워드 - 고스트
# 키워드들:
# - 고스트PC
#
# 클러스터 91: 대표 키워드 - 압박
# 키워드들:
# - 실적 압박
# - 실적 우수자
# - KPI 압박
# - 실적
# - 압박
#
# 클러스터 94: 대표 키워드 - 검증
# 키워드들:
# - 본사 검증
# - 상품 검증
# - 검증 부족
# - 데이터 검증
# - 철저한 검증과 통제
# - KPI 검증
#
# 클러스터 119: 대표 키워드 - 보완
# 키워드들:
# - 보완
# - 서류 미비
# - 보완기한 준수
# - 보완완료
# - 서류 보완
# - 미비점
# - 미비사항
# - 매뉴얼 미비
# - 보완 충분
# - 미비 보완
# - 미비서류 보완
# - 보완 완료
#
# 클러스터 63: 대표 키워드 - 화면
# 키워드들:
# - 타사 시스템 차이
# - 화면 업데이트
# - 화면 안내
# - 대리인 등록 업데이트
# - 매뉴얼 업데이트
# - 시스템 업데이트
# - 화면 문제
# - 앱 화면
# - 골드넷+ 화면 업데이트
# - HTS 화면 차이
#
# 클러스터 102: 대표 키워드 - 가이드라인
# 키워드들:
# - 투자 권유 가이드라인
# - 광고 가이드라인
#
# 클러스터 168: 대표 키워드 - 수단
# 키워드들:
# - 매수단가
#
# 클러스터 74: 대표 키워드 - 민원
# 키워드들:
# - 민원 발생
# - 민원
# - 금융감독원 민원
# - 민원 발생 가능
# - 고객 민원
#
# 클러스터 111: 대표 키워드 - 성과급
# 키워드들:
# - 성과급제도
# - 성과급 회수
# - 성과급 연동
# - 연동 문제
# - 성과급 문제
#
# 클러스터 36: 대표 키워드 - 이자
# 키워드들:
# - 이자 산정
# - 채권 이자 지급
# - 이자 미납
#
# 클러스터 217: 대표 키워드 - 시니어
# 키워드들:
# - 시니어
# - 시니어부족
# - 시니어급 내부통제
#
# 클러스터 7: 대표 키워드 - 필요
# 키워드들:
# - 게시물 필요
# - 보강 필요
# - 조직개편
# - 알럿 필요
# - 조직개편 필요
#
# 클러스터 243: 대표 키워드 - 계약
# 키워드들:
# - 계약 과정
# - 계약 관리
#
# 클러스터 85: 대표 키워드 - 저하
# 키워드들:
# - 동기부여 부족
# - 저하
# - 동기부여 저하
# - 사기 저하
# - 영업력 저하
#
# 클러스터 203: 대표 키워드 - 연금
# 키워드들:
# - 연금 해지 계좌
# - 연금저출 시스템
# - 퇴직연금 화면 개선
# - 연금저축
# - 개인연금
# - 퇴직연금
# - 퇴직연금 매도업무
# - 퇴직연금업무
# - 연금 업무
# - 퇴직연금 시스템
#
# 클러스터 116: 대표 키워드 - 집중
# 키워드들:
# - 파워 집중
# - 업무집중화팀
# - 권한 집중
# - 디지털집중화팀
# - 콜 집중화
#
# 클러스터 211: 대표 키워드 - 담보
# 키워드들:
# - 무담보 미수채권 관리
# - 담보 관리
# - 담보부족
# - 담보리스크
# - 주식담보 대출
#
# 클러스터 199: 대표 키워드 - 센티
# 키워드들:
# - 팀 인센티브 제도
# - 인센티브
# - 인센티브 관리
# - 인센티브 문제
# - 인센티브 지급
#
# 클러스터 65: 대표 키워드 - 파악
# 키워드들:
# - 상황 파악
# - 현황 파악
#
# 클러스터 98: 대표 키워드 - 증권
# 키워드들:
# - 미래에셋증권
# - 증권 본업
# - 증권사관학교
#
# 클러스터 114: 대표 키워드 - 중심
# 키워드들:
# - 고객중심
# - 수익 중심주의
# - 수익 중심 경영
# - 고객 중심
# - 시장중심
#
# 클러스터 20: 대표 키워드 - 권한
# 키워드들:
# - PB 권한
# - 내부통제 권한 부족
# - 업무 권한 과다
# - 컨트롤타워 권한
# - 권한 통제
# - 권한 부여자
# - 권한
# - 컨트롤타워 조직
#
# 클러스터 143: 대표 키워드 - 관행
# 키워드들:
# - 주문 관행
# - 메신저 처리 관행
# - 부적절한 관행
# - 관행적 절차
# - 조직 부정적 관행
#
# 클러스터 109: 대표 키워드 - 처리
# 키워드들:
# - 큰 금액 처리
# - 수동 처리
# - 고객 방문 처리
#
# 클러스터 207: 대표 키워드 - 부재
# 키워드들:
# - 시스템 부재
# - 대직자 부재
# - 팀장 부재
# - 관리 시스템 부재
# - 기준 부재
# - 리더십 부재
# - 운용역 부재
# - 책임자 부재
#
# 클러스터 25: 대표 키워드 - 사고
# 키워드들:
# - 사고 위험성
# - 금융 사고
# - 사고상품 관리
# - 사고발생 확률
# - 위험성
# - 자금 사고
# - 본사 사고
# - 문제 발생
# - 금융사고
# - GIB 사고
# - 사고 발생
# - 사고
# - 리스크 발생
#
# 클러스터 206: 대표 키워드 - 어려움
# 키워드들:
# - 업무 어려움
# - 답변 어려움
# - 통화 어려움
# - 영업 어려움
# - 통제 어려움
# - 업무처리 어려움
# - 영업환경 어려움
# - 어려움
#
# 클러스터 166: 대표 키워드 - 법무
# 키워드들:
# - 법무실
#
# 클러스터 117: 대표 키워드 - 예외
# 키워드들:
# - 예외연장 기준
# - 예외적 업무
# - 예외 부서 점검
# - 예외업무 매뉴얼
#
# 클러스터 69: 대표 키워드 - 제도
# 키워드들:
# - 정부제도
# - 숙려제도
#
# 클러스터 51: 대표 키워드 - 구축
# 키워드들:
# - 관계 확인
# - 신뢰관계 구축
# - 시스템 구축
#
# 클러스터 159: 대표 키워드 - 지시
# 키워드들:
# - 상급자 지시 문제
# - 강압적 지시
# - 부당한 지시
#
# 클러스터 188: 대표 키워드 - 일시
# 키워드들:
# - 일시적 중단
#
# 클러스터 79: 대표 키워드 - 투명
# 키워드들:
# - 업무능력 향상
# - 정보 투명성
# - 투명성 향상
#
# 클러스터 122: 대표 키워드 - 개인
# 키워드들:
# - 개인 역량
# - 개인 포기
#
# 클러스터 135: 대표 키워드 - 공개
# 키워드들:
# - 투명한 공개
# - 최종 결론 공개
# - 정보 공개
# - 필벌 내용 공개
#
# 클러스터 35: 대표 키워드 - 매뉴얼
# 키워드들:
# - 매뉴얼 부족
# - 접근 불가
# - 망고매뉴얼
# - 매뉴얼 등재 누락
# - 가이드 매뉴얼
# - 매뉴얼 등재
# - 업무매뉴얼 필요
# - 매뉴얼 정비
# - 업무매뉴얼 부족
# - 매뉴얼
# - 가이드 부족
# - 업무 가이드
# - 매뉴얼 접근
# - 업무 매뉴얼
# - 법인금융 업무 매뉴얼
#
# 클러스터 165: 대표 키워드 - 해석
# 키워드들:
# - 명확한 해석
#
# 클러스터 162: 대표 키워드 - 노력
# 키워드들:
# - 인당 노력
#
# 클러스터 160: 대표 키워드 - 가격
# 키워드들:
# - 매수가격
#
# 클러스터 54: 대표 키워드 - 매매
# 키워드들:
# - 오프라인 매매
# - 오프라인 고객
# - 매매주문
# - 임직원 자기매매
# - 무리한 매매
# - 고객계좌 임의매매
# - 본인계좌 매매
# - 매매시스템
#
# 클러스터 158: 대표 키워드 - 경향
# 키워드들:
# - 부적절한 경향
#
# 클러스터 123: 대표 키워드 - 회수
# 키워드들:
# - 회수불가
# - 미수채권 회수
# - 채권 회수 전담팀
# - 교육 회수
#
# 클러스터 89: 대표 키워드 - 소통
# 키워드들:
# - 세대 간 소통
# - CEO 소통
# - 정보 소통
# - 소통 문제
# - 소통 어려움
# - 고객 소통
#
# 클러스터 221: 대표 키워드 - 변화
# 키워드들:
# - 경영진 변화 필요
# - 제도적 변화
# - 시장 변화
# - 변화 없음
# - 인식 변화
#
# 클러스터 237: 대표 키워드 - 전문가
# 키워드들:
# - 전문가 배치
# - 전문가 필요
# - 전문가 부재
# - 전문가 영업
# - 전문가 부족
#
# 클러스터 156: 대표 키워드 - 더블
# 키워드들:
# - 더블카운팅
#
# 클러스터 60: 대표 키워드 - 운영
# 키워드들:
# - 운영리스크
# - 지점 운영
# - 고유자금 운영
#
# 클러스터 231: 대표 키워드 - 형식
# 키워드들:
# - 형식적 관행
# - 형식적 승인
# - 형식적 통제
# - 형식적
# - 형식적 점검
#
# 클러스터 214: 대표 키워드 - 위험
# 키워드들:
# - 위험
# - 고지팀
# - 위험 고지
# - 위험도 정보
#
# 클러스터 53: 대표 키워드 - 법인
# 키워드들:
# - 법인카드
# - 법인카드 리스크
# - 법인카드 사용 통제
# - 법인자금 유출
# - 정보 유출 리스크
# - 법인 비딩
#
# 클러스터 186: 대표 키워드 - 감점
# 키워드들:
# - KPI 감점 가능성
#
# 클러스터 213: 대표 키워드 - 세금
# 키워드들:
# - 세금 관련 입금
# - 세금 관련 프로세스
# - 세금 문제
#
# 클러스터 209: 대표 키워드 - 대비
# 키워드들:
# - 대비
# - 타사 대비
#
# 클러스터 115: 대표 키워드 - 인감
# 키워드들:
# - 법인 인감
# - 사용인감 효력
# - 인감
#
# 클러스터 205: 대표 키워드 - 시간
# 키워드들:
# - 시간 소요
# - 투자 시간
# - 시간 소모
# - 대출업무 시간
#
# 클러스터 183: 대표 키워드 - 자산
# 키워드들:
# - 고객 자산
# - 고유자산
# - 자산 유출
#
# 클러스터 245: 대표 키워드 - 열사
# 키워드들:
# - 계열사 업무
# - 신한계열사 입금
#
# 클러스터 154: 대표 키워드 - 상담
# 키워드들:
# - 상담일지
#
# 클러스터 107: 대표 키워드 - 승인
# 키워드들:
# - 처리 지연
# - 심사부 승인 지연
# - 업무처리 지연
# - 승인 프로세스
# - 책임자 승인
# - CDD 승인 지연
# - 승인 절차
# - 책임자 승인 프로세스
# - 부서 응답 지연
# - 승인 처리
# - 지연
#
# 클러스터 180: 대표 키워드 - 방식
# 키워드들:
# - 쪽지 전달방식
#
# 클러스터 152: 대표 키워드 - 친밀
# 키워드들:
# - 친밀감
#
# 클러스터 100: 대표 키워드 - 창구
# 키워드들:
# - 디지털창구
# - 고객 창구 대기
#
# 클러스터 150: 대표 키워드 - 난국
# 키워드들:
# - 난국
#
# 클러스터 171: 대표 키워드 - 금리
# 키워드들:
# - 채권금리
# - 협의금리
# - 금리 경쟁력
#
# 클러스터 201: 대표 키워드 - 엑셀
# 키워드들:
# - 엑셀
# - 엑셀 업로드
#
# 클러스터 191: 대표 키워드 - 설명
# 키워드들:
# - 설명 부족
# - 고객 설명
# - 상품 설명
#
# 클러스터 238: 대표 키워드 - 등록
# 키워드들:
# - 매뉴얼 등록
# - 전문투자자 등록
# - 유치자 등록
#
# 클러스터 148: 대표 키워드 - 모범
# 키워드들:
# - 모범
#
# 클러스터 146: 대표 키워드 - 로테이션
# 키워드들:
# - 로테이션
#
# 클러스터 83: 대표 키워드 - 기능
# 키워드들:
# - 시스템 알람 기능
# - 알람
# - 녹음기능
# - 시스템 감시 기능
#
# 클러스터 144: 대표 키워드 - 우울
# 키워드들:
# - 우울감
#
# 클러스터 142: 대표 키워드 - 부적합
# 키워드들:
# - 시점 부적합
#
# 클러스터 140: 대표 키워드 - 개별
# 키워드들:
# - 개별 공시
#
# 클러스터 138: 대표 키워드 - 대량
# 키워드들:
# - 대량 메일
#
# 클러스터 136: 대표 키워드 - 의혹
# 키워드들:
# - 카르텔 의혹
#
# 클러스터 134: 대표 키워드 - 온도
# 키워드들:
# - 온도차
#
# 클러스터 235: 대표 키워드 - 추가
# 키워드들:
# - 기능 추가
# - 업무 추가
# - 추가 통제 불필요
#
# 클러스터 132: 대표 키워드 - 출장
# 키워드들:
# - 출장
#
# 클러스터 219: 대표 키워드 - 견제
# 키워드들:
# - 부서 견제
# - 견제와 균형
# - 견제 시스템
#
# 클러스터 41: 대표 키워드 - 임원
# 키워드들:
# - 임원 모럴헤저드
# - 임원 균형
# - 임원 솔선수범
# - 모럴헤저드
# - 임원 사명감
#
# 클러스터 121: 대표 키워드 - 결재
# 키워드들:
# - 결재 시스템
# - 결재 편의성
# - 결재 위임
# - 결재 절차
#
# 클러스터 130: 대표 키워드 - 미반
# 키워드들:
# - KPI 미반영
#
# 클러스터 151: 대표 키워드 - 전자문서
# 키워드들:
# - 전자문서 고도화
# - 전자문서 시스템
# - 전자문서
#
# 클러스터 233: 대표 키워드 - 이해
# 키워드들:
# - 이해 어려움
# - 현장 이해 부족
# - 이해상충
# - 업무 프로세스 이해
# - 내부통제 이해 부족
#
# 클러스터 128: 대표 키워드 - 그레이
# 키워드들:
# - 그레이존
#
# 클러스터 39: 대표 키워드 - 단가
# 키워드들:
# - 단가 입력
# - 단가 입력 프로세스
# - 단가 수작업
# - 수작업
# - 단가 수기입력
#
# 클러스터 96: 대표 키워드 - 무시
# 키워드들:
# - 실무자 의견 무시
# - 무시
# - 지점 특성 무시
#
# 클러스터 22: 대표 키워드 - 신규
# 키워드들:
# - 신규고객
# - 신규 채용
# - 자기사람 채용
#
# 클러스터 126: 대표 키워드 - 마스
# 키워드들:
# - 주민번호 마스킹
#
# 클러스터 239: 대표 키워드 - 외국인
# 키워드들:
# - 거주외국인
# - 외국인 업무
#
# 클러스터 248: 대표 키워드 - 성장
# 키워드들:
# - 지속 성장
#
# 클러스터 244: 대표 키워드 - 언론보도
# 키워드들:
# - 언론보도
#
# 클러스터 240: 대표 키워드 - 경쟁
# 키워드들:
# - 경쟁사
#
# 클러스터 236: 대표 키워드 - 책임감
# 키워드들:
# - 책임감
#
# 클러스터 232: 대표 키워드 - 벤치마킹
# 키워드들:
# - 벤치마킹
#
# 클러스터 228: 대표 키워드 - 이용
# 키워드들:
# - SNS 이용
#
# 클러스터 198: 대표 키워드 - 날인
# 키워드들:
# - 전자직인 날인
# - 날인
#
# 클러스터 224: 대표 키워드 - 수익금
# 키워드들:
# - 수익금
#
# 클러스터 84: 대표 키워드 - 체제
# 키워드들:
# - 2인 체제
# - 3인 체제
#
# 클러스터 220: 대표 키워드 - 신입사원
# 키워드들:
# - 신입사원
#
# 클러스터 216: 대표 키워드 - 대체
# 키워드들:
# - 예수금 대체
#
# 클러스터 212: 대표 키워드 - 컴플라이언스
# 키워드들:
# - 컴플라이언스
#
# 클러스터 208: 대표 키워드 - 포상
# 키워드들:
# - 포상
#
# 클러스터 167: 대표 키워드 - 주의
# 키워드들:
# - 온정주의
# - 보신주의
# - 안정주의
#
# 클러스터 204: 대표 키워드 - 문제점
# 키워드들:
# - 문제점
#
# 클러스터 99: 대표 키워드 - 설계
# 키워드들:
# - 설계단계
# - 잘못 설계
#
# 클러스터 196: 대표 키워드 - 모욕
# 키워드들:
# - 모욕
#
# 클러스터 192: 대표 키워드 - 만족
# 키워드들:
# - 만족
#
# 클러스터 190: 대표 키워드 - 단순화
# 키워드들:
# - 단순화
#
# 클러스터 184: 대표 키워드 - 적극
# 키워드들:
# - 적극적 해결
#
# 클러스터 182: 대표 키워드 - 헤리티지
# 키워드들:
# - 헤리티지
#
# 클러스터 177: 대표 키워드 - 이메일
# 키워드들:
# - 이메일
#
# 클러스터 169: 대표 키워드 - 고충
# 키워드들:
# - 고충
#
# 클러스터 108: 대표 키워드 - 전문성
# 키워드들:
# - 전문성 부족
# - 업무전문성
# - 부서장 전문성
# - 전문성 부족 인사 이동
#
# 클러스터 125: 대표 키워드 - 선물
# 키워드들:
# - 해외선물
# - 선물/옵션
#
# 클러스터 82: 대표 키워드 - 이어폰
# 키워드들:
# - 이어폰
#
# 클러스터 67: 대표 키워드 - 정책
# 키워드들:
# - KPI 일관성
# - 운영정책
# - KPI 정책
# - 정책
# - 정책 변화
# - 정책 일관성
#
# 클러스터 189: 대표 키워드 - 브랜드
# 키워드들:
# - 브랜드 혜택
#
# 클러스터 157: 대표 키워드 - 상승
# 키워드들:
# - BEP 상승
#
# 클러스터 175: 대표 키워드 - 성향
# 키워드들:
# - 투자상담사
# - 투자성향 정보
# - 개인성향
# - 투자성향지 문제
#
# 클러스터 153: 대표 키워드 - 행정
# 키워드들:
# - 보여주기식 행정
#
# 클러스터 12: 대표 키워드 - 회사
# 키워드들:
# - 좋은 분위기
# - 본사 분위기
# - 회사 정상화
# - 회사 위상
# - 회사애정
# - 회사 분위기
#
# 클러스터 149: 대표 키워드 - 예시
# 키워드들:
# - 예시글 제공
#
# 클러스터 120: 대표 키워드 - 대안
# 키워드들:
# - 대안 부족
# - 대안
#
# 클러스터 195: 대표 키워드 - 일원화
# 키워드들:
# - 안내 일원화
# - 매뉴얼 일원화
# - 업무 일원화 필요
# - 시스템 일원화
# - 일원화
#
# 클러스터 145: 대표 키워드 - 달성
# 키워드들:
# - KPI 달성
#
# 클러스터 193: 대표 키워드 - 점심시간
# 키워드들:
# - 점심시간
# - 점심시간 교대
#
# 클러스터 137: 대표 키워드 - 상부
# 키워드들:
# - 투상부 적극성
#
# 클러스터 133: 대표 키워드 - 기간
# 키워드들:
# - 유예기간
#
# 클러스터 129: 대표 키워드 - 재고
# 키워드들:
# - KPI 재고
#
# 클러스터 250: 대표 키워드 - 보관
# 키워드들:
# - 보관
#
# 클러스터 249: 대표 키워드 - 사후관리
# 키워드들:
# - 사후관리
#
# 클러스터 242: 대표 키워드 - 연구
# 키워드들:
# - 정서적 연구
#
# 클러스터 234: 대표 키워드 - 노동조합
# 키워드들:
# - 노동조합
#
# 클러스터 222: 대표 키워드 - 미흡
# 키워드들:
# - 본사 내부통제 미흡
# - 미흡
# - 매뉴얼 미흡
#
# 클러스터 226: 대표 키워드 - 차단
# 키워드들:
# - 활용 차단
#
# 클러스터 218: 대표 키워드 - 실명
# 키워드들:
# - 실명제
#
# 클러스터 194: 대표 키워드 - 덕성
# 키워드들:
# - 비도덕성
#
# 클러스터 185: 대표 키워드 - 포용
# 키워드들:
# - 포용
#
# 클러스터 173: 대표 키워드 - 권위
# 키워드들:
# - 권위적 PB
#
# 클러스터 161: 대표 키워드 - 미스터리
# 키워드들:
# - 미스터리쇼핑
#
# 클러스터 76: 대표 키워드 - 이율
# 키워드들:
# - 이율
#
# 클러스터 72: 대표 키워드 - 빡빡
# 키워드들:
# - 빡빡함
#
# 클러스터 141: 대표 키워드 - 참고
# 키워드들:
# - 타사 참고
#
# 클러스터 64: 대표 키워드 - 표준화
# 키워드들:
# - 표준화
#
# 클러스터 241: 대표 키워드 - 공모
# 키워드들:
# - 공모 의심
#
# 클러스터 225: 대표 키워드 - 계산
# 키워드들:
# - 증거금계산
#
# 클러스터 202: 대표 키워드 - 묵인
# 키워드들:
# - 묵인
#
# 클러스터 112: 대표 키워드 - 조정
# 키워드들:
# - KPI 조정
#
# 클러스터 181: 대표 키워드 - 발행
# 키워드들:
# - 발행어음
#
# 클러스터 80: 대표 키워드 - 강점
# 키워드들:
# - 강점
#
# 클러스터 147: 대표 키워드 - 트라우마
# 키워드들:
# - 트라우마
#
# 클러스터 230: 대표 키워드 - 드라이브
# 키워드들:
# - KPI 드라이브
#
# 클러스터 210: 대표 키워드 - 의사소통
# 키워드들:
# - 의사소통
#
# 클러스터 88: 대표 키워드 - 내부고발자
# 키워드들:
# - 내부고발자
#
# 클러스터 68: 대표 키워드 - 각심
# 키워드들:
# - 경각심
#
# 클러스터 131: 대표 키워드 - 불명
# 키워드들:
# - 불명확성

# %%
df_keyword
# Out:
#      Unnamed: 0  idx                               k1  \
# 0             1    1                              NaN
# 1             2    2                              NaN
# 2             3    3                              NaN
# 3             4    4                              NaN
# 4             5    5                              NaN
# ..          ...  ...                              ...
# 231         237  237      1. 국내주식\n2. 퇴직연금\n3. 제도적 변화
# 232         238  238    1. 승인 절차\n2. 책임자 부재\n3. 개선 필요
# 233         240  240  1. 승인 프로세스\n2. 책임자 부재\n3. 개선 필요
# 234         241  241     1. 책임자 부재\n2. 승인 프로세스\n3. 개선
# 235         242  242         1. IB영업\n2. 법인영업\n3. 리스크
#
#                               k2  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ..                           ...
# 231                          NaN
# 232                          NaN
# 233                          NaN
# 234           1. 서류 미비\n2. 보완 완료
# 235  1. 라임사태\n2. 서류간소화\n3. 법인 비딩
#
#                                                     k3  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 231                                                NaN
# 232          1. 시스템 구축\n2. 전자문서\n3. 매뉴얼 정비\n4. 담당자 최신화
# 233     1. 시스템 구축\n2. 업무 개선\n3. 전자문서\n4. 본사부서\n5. 대직체계
# 234  1. 해외주식 단가입력\n2. 대주주 대출\n3. 망고매뉴얼\n4. 퇴직연금업무\n...
# 235                                                NaN
#
#                              k4   k5  \
# 0                           NaN  NaN
# 1       1. 브랜드 혜택\n2. 개인적 영업 타격  NaN
# 2                           NaN  NaN
# 3                           NaN  NaN
# 4    1. KPI 달성\n2. 심적 부담\n3. 모범  NaN
# ..                          ...  ...
# 231                         NaN  NaN
# 232                         NaN  NaN
# 233                         NaN  NaN
# 234                         NaN  NaN
# 235                         NaN  NaN
#
#                                                    k6  \
# 0                                                 NaN
# 1            1. 영업과 본사 간 괴리\n2. 일률적인 절차 적용\n3. 투명성 향상
# 2                     1. 준법 통제\n2. 인적 구성\n3. 내부 통제 부족
# 3    1. 우울감\n2. 젊은 인력 구성\n3. 정서적 연구\n4. 로열티\n5. 직원 사기
# 4                                                 NaN
# ..                                                ...
# 231                          1. 부서수익\n2. 내부통제\n3. 리스크
# 232                                           1. 순환보직
# 233                       1. 장기근무\n2. 소통 어려움\n3. 순환보직
# 234                                   1. 업무팀\n2. 순환보직
# 235                          1. 부서수익\n2. 내부통제\n3. 리스크
#
#                          km_1                  km_2  \
# 0                          []                    []
# 1                          []                    []
# 2                          []                    []
# 3                          []                    []
# 4                          []                    []
# ..                        ...                   ...
# 231      [국내주식, 퇴직연금, 제도적 변화]                    []
# 232    [승인 절차, 책임자 부재, 개선 필요]                    []
# 233  [승인 프로세스, 책임자 부재, 개선 필요]                    []
# 234     [책임자 부재, 승인 프로세스, 개선]        [서류 미비, 보완 완료]
# 235         [IB영업, 법인영업, 리스크]  [라임사태, 서류간소화, 법인 비딩]
#
#                                                km_3                 km_4 km_5  \
# 0                                                []                   []   []
# 1                                                []  [브랜드 혜택, 개인적 영업 타격]   []
# 2                                                []                   []   []
# 3                                                []                   []   []
# 4                                                []  [KPI 달성, 심적 부담, 모범]   []
# ..                                              ...                  ...  ...
# 231                                              []                   []   []
# 232                 [시스템 구축, 전자문서, 매뉴얼 정비, 담당자 최신화]                   []   []
# 233               [시스템 구축, 업무 개선, 전자문서, 본사부서, 대직체계]                   []   []
# 234  [해외주식 단가입력, 대주주 대출, 망고매뉴얼, 퇴직연금업무, 세금 관련 프로세스]                   []   []
# 235                                              []                   []   []
#
#                                     km_6  \
# 0                                     []
# 1      [영업과 본사 간 괴리, 일률적인 절차 적용, 투명성 향상]
# 2               [준법 통제, 인적 구성, 내부 통제 부족]
# 3    [우울감, 젊은 인력 구성, 정서적 연구, 로열티, 직원 사기]
# 4                                     []
# ..                                   ...
# 231                    [부서수익, 내부통제, 리스크]
# 232                               [순환보직]
# 233                 [장기근무, 소통 어려움, 순환보직]
# 234                          [업무팀, 순환보직]
# 235                    [부서수익, 내부통제, 리스크]
#
#                                                   km_f
# 0                                                   []
# 1    [브랜드 혜택, 개인적 영업 타격, 영업과 본사 간 괴리, 일률적인 절차 적용, 투...
# 2                             [준법 통제, 인적 구성, 내부 통제 부족]
# 3                  [우울감, 젊은 인력 구성, 정서적 연구, 로열티, 직원 사기]
# 4                                  [KPI 달성, 심적 부담, 모범]
# ..                                                 ...
# 231              [국내주식, 퇴직연금, 제도적 변화, 부서수익, 내부통제, 리스크]
# 232  [승인 절차, 책임자 부재, 개선 필요, 시스템 구축, 전자문서, 매뉴얼 정비, 담...
# 233  [승인 프로세스, 책임자 부재, 개선 필요, 시스템 구축, 업무 개선, 전자문서, ...
# 234  [책임자 부재, 승인 프로세스, 개선, 서류 미비, 보완 완료, 해외주식 단가입력,...
# 235  [IB영업, 법인영업, 리스크, 라임사태, 서류간소화, 법인 비딩, 부서수익, 내부...
#
# [236 rows x 15 columns]

# %%
# representative_keywords
cluster_dict



# 키를 찾는 함수
def find_key_by_value_list(value_list, dictionary):
    key_list = []
    for value in value_list:
        for key, values in dictionary.items():
            if value in values:
                key_list.append(key)
    return key_list


key_list = []
key_list_1 = []
key_list_2 = []
key_list_3 = []
key_list_4 = []
key_list_5 = []
key_list_6 = []

# 딕셔너리로 변수 초기화
key_lists = {f"key_list_{i}": [] for i in range(1, 7)}

for i in range(len(df_keyword)):
    # print(df_keyword.loc[i, f"km_1"])

    key_list0 = find_key_by_value_list(df_keyword.loc[i, f"km_f"], cluster_dict)
    key_list1 = find_key_by_value_list(df_keyword.loc[i, f"km_1"], cluster_dict)
    key_list2 = find_key_by_value_list(df_keyword.loc[i, f"km_2"], cluster_dict)
    key_list3 = find_key_by_value_list(df_keyword.loc[i, f"km_3"], cluster_dict)
    key_list4 = find_key_by_value_list(df_keyword.loc[i, f"km_4"], cluster_dict)
    key_list5 = find_key_by_value_list(df_keyword.loc[i, f"km_5"], cluster_dict)
    key_list6 = find_key_by_value_list(df_keyword.loc[i, f"km_6"], cluster_dict)

    key_list.append(list(set(key_list0)))
    key_list_1.append(list(set(key_list1)))
    key_list_2.append(list(set(key_list2)))
    key_list_3.append(list(set(key_list3)))
    key_list_4.append(list(set(key_list4)))
    key_list_5.append(list(set(key_list5)))
    key_list_6.append(list(set(key_list6)))
    # print(key_list1)

# %%
df_keyword["km_f_gp"] = key_list
df_keyword["km_1_gp"] = key_list_1
df_keyword["km_2_gp"] = key_list_2
df_keyword["km_3_gp"] = key_list_3
df_keyword["km_4_gp"] = key_list_4
df_keyword["km_5_gp"] = key_list_5
df_keyword["km_6_gp"] = key_list_6

df_keyword.to_csv("result_final.csv")

# %%
df_final = pd.read_csv("result_final.csv")

# df 에 저장된 리스트 형식 텍스트를 실제 list 로 변환
df_final["km_f"] = df_final["km_f_gp"].apply(ast.literal_eval)
for i in range(1,7):
    df_final[f"km_{i}_gp"] = df_final[f"km_{i}"].apply(ast.literal_eval)

# %%
df_final["km_f"] = df_final["km_f_gp"].apply(ast.literal_eval)
df_final.loc[0, "km_f"]
# Out:
# []

# %%
# 7. 결과 출력
for label, keyword_list in cluster_dict.items():
    print(f"\n클러스터 {label + 1}: 대표 키워드 - {representative_keywords[label]}")
    print("키워드들:")
    for keyword in keyword_list:
        print(f"- {keyword}")

columns = ['label','keyword','keywords','cnt','idx_list']
df_result = pd.DataFrame(columns=columns)
# label 별 대표키워드, idx 맵핑 처리
for label, keyword_list in cluster_dict.items():
    cnt = 0
    idx_list = []
    for i in range(len(df_final)) :
        if label in ast.literal_eval( df_final.loc[i,"km_f_gp"]):
            idx_list.append(df_final.loc[i, "idx"])
            cnt += 1

    # 각 행 데이터 생성
    row = {
        'label': label,
        'keyword': representative_keywords[label],  # 대표 키워드
        'keywords': keyword_list,  # 키워드 목록
        'cnt': cnt,  # 키워드 개수
        'idx_list': idx_list  # 키워드의 임의 인덱스
    }
    # DataFrame에 추가
    df_result = pd.concat([df_result, pd.DataFrame([row])], ignore_index=True)
# Out:
# 클러스터 10: 대표 키워드 - 직원
# 키워드들:
# - 시스템 개선
# - 직원 리드
# - 고객응대
# - 직원 사기
# - 실행의지
# - 임피직원 문제
# - 직원 인성 확인
# - 적절하지 않음
# - 불만
# - 경력직원 검증
# - 부점 직원 자질
# - 직원 불만
# - 교육 접근성
# - 직원 인식
# - 출금 방법 개선
# - 내부통제 수준
# - 교육 필요
# - 직원 희생
# - Account Risk
# - 직원 발전
# - 본사 직원
# - 개선
# - 내부통제 인식
# - 불편함
# - 공지 필요
# - 인식 수준
# - 관련 내용 공지
# - 시스템 교육
# - 업무 교육
# - 중요성 인식
# - 업무 시스템 개선
# - 경력 부족
# - 본사직원
# - 내부통제 교육
# - 직원 마인드
# - 시스템 개선 필요
# - 직원 공지
# - 높은 KPI
# - 직원 인식 부족
# - HTS 교육 필요
# - 직원
# - 직원 실망감 해소
# - 본사 마인드
# - 교육 개선
# - 로열티
# - 개선 필요 없음
# - 절차 개선
# - KPI
# - 인식 개선
# - 교육 필요성
# - 응대 직원 부족
# - 내부통제 중요성 인식
# - HTS
# - 직원 교육
# - 본사 직원 마인드 개선
# - 업무 개선 건의
# - 완벽하지 않음
# - IRP
# - 업무 개선
# - 프론트직원
# - 업무공지
# - 신분증
# - 내부통제 교육 부족
# - PB 인식
# - PB 교육
# - 업무 공유
# - ELB
# - 개선 필요
# - PB
# - MTS
# - 시스템 불만
# - 직원의 태도 불만
# - 실무교육 부족
# - 마인드 개선
# - Smeet
# - 교육
# - 내부통제 중요성
# - 안일한 태도
# - PWM
# - 절차 개선 필요
# - 신분증 인식
# - 비관리계좌 고객 응대
# - 경력직
# - R&R
# - 미비함
# - CRM
# - 직원 로열티 부족
# - 공지 부족
# - IB
# - 시스템 공유
# - 금전대차 위반 인식
# - 직원의지
# - 전직원 공유
# - 고객 응대
# - GMS
# - 고객 불만
# - 본사 응대 태도 문제
# - 본사 불신감
# - 인식부족
#
# 클러스터 16: 대표 키워드 - 증가
# 키워드들:
# - 영업과 수익 증가
# - 업무량 증가
# - 업무량 차이
# - 인원 증가
# - 리스크 증가
# - 감사 횟수 증가
# - 업무량 과다
#
# 클러스터 105: 대표 키워드 - 규정
# 키워드들:
# - 규정 확인
# - 내부통제 규정
# - 규정 반영
# - 영업강조
# - 규정 강조
#
# 클러스터 19: 대표 키워드 - 녹취
# 키워드들:
# - 녹취 장비
# - 녹취 장비 문제
# - 유선업무
# - 대면 녹취
# - IT 인력 및 장비
# - 필수어 녹취
# - 대면 녹취 점검
# - 녹취 시스템
# - 녹취장비
# - 대면녹취
# - 녹취시스템 간소화
# - SMEET 녹취 에러
# - 녹취 장비 교체
# - 전화녹취 개선
# - 유선 녹취 없음
# - 녹취
#
# 클러스터 61: 대표 키워드 - 관리자
# 키워드들:
# - 관리자 제도 폐쇄
# - 관리자 제도 폐지
# - 관리자 등록
# - 상품별 관리자
# - 랩 관리자 변경
#
# 클러스터 30: 대표 키워드 - 프로세스
# 키워드들:
# - 면담 불필요
# - 면담 프로세스
# - 업무 프로세스 개선
# - 업무 프로세스
# - E-mail 프로세스
# - 판매 프로세스
# - 환전우대
# - 환전 프로세스
# - 상식적인 프로세스
# - 프로세스 개선
#
# 클러스터 70: 대표 키워드 - 주문
# 키워드들:
# - 작은 실수
# - 주문 실수
# - 주문증빙
# - 주문실수
# - 고객 주문 대행
# - 증빙 없는 주문
# - 대리주문
# - 전화주문 증빙
# - 고객 주문
# - 전화 대리
#
# 클러스터 28: 대표 키워드 - 내부통제
# 키워드들:
# - 프로세스 재정비
# - 내부통제
# - 내부통제 문제
# - 내부통제 허술
# - 내부통제 필요
# - 내부통제 강화 필요
# - 내부통제 과다
# - 강화
# - 내부통제 제약
# - 내부통제 재정립
# - 내부통제 강화
# - 시스템 강화
# - 내부통제 강도
# - 자질 강화
# - 내부통제 재정비
# - 제도 재정비
#
# 클러스터 42: 대표 키워드 - 인원
# 키워드들:
# - 인원 확충
# - 파견인원 부족
# - 파견 인원
# - 확충 필요
#
# 클러스터 139: 대표 키워드 - 재개
# 키워드들:
# - 사규 재개정
# - 법규 재개정
#
# 클러스터 179: 대표 키워드 - 징계
# 키워드들:
# - 징계 조치
# - 중징계
# - 징계 수위
# - 평가와 징계
# - 징계
#
# 클러스터 8: 대표 키워드 - 대출
# 키워드들:
# - 신용 등급
# - 대출 기준
# - 대주주 대출
# - 대출
# - 여신대출
# - 대출 기준 축소
# - 신용/대출 통제
# - 대출 등급
# - 대주주 대출 시스템
# - 신용 업무
# - 신용 대출
# - 투자등급
# - 대출 자금
# - 신용대출
# - 신용/대출 시뮬레이션
# - 리츠 대출 문제
# - 신용/대출 리스크
# - 신용/대출 처리 기준
# - 등급 변경
# - 대주주 대출업무
#
# 클러스터 11: 대표 키워드 - 고객
# 키워드들:
# - 온라인가입
# - 고객 이탈
# - 고객 자금 횡령
# - 고객지원팀장
# - 고객 정보 전송
# - 고객 입금
# - 온라인 고객
# - 고객 동의 없는 등록
# - 모바일 고객
# - 고객 이탈 가능성
# - 고객 안내
# - 고객 정보 갱신
# - 고객동의 절차
#
# 클러스터 26: 대표 키워드 - 상품
# 키워드들:
# - 상품 가입 미비
# - 금융투자상품
# - 경쟁력 데이터
# - 안전상품
# - 금융상품 경쟁력
# - 금융상품 채권
# - 금융상품 가입
# - 경쟁력 없는 상품
# - 채권상품부
# - 금융상품 절차 부족
# - 상품 가입 보완 부족
# - 경쟁력
# - 기업금융
# - 상품경쟁력
# - 금융상품 녹취
# - 채권 커뮤니케이션
# - 상품 선가입
# - 중장기성 상품
# - 금융상품 서류
# - 채권상품
# - 채권 고령자상품
# - 채권 매도
# - 금융상품 공부
# - 금융상품
# - 상품 선가입 미비
# - 채권잔고
#
# 클러스터 197: 대표 키워드 - 문의
# 키워드들:
# - 업무 문의
# - 문의부재
# - 문의 처리
# - 문의
# - 업무문의
# - 고객 문의
# - 문의 필요
#
# 클러스터 215: 대표 키워드 - 주식
# 키워드들:
# - 해외주식 평가액
# - 해외주식 주문
# - 해외주식 입력 프로세스
# - 해외주식 시스템 개선
# - 해외주식 자료 부족
# - 해외주식 프로세스
# - 해외주식 시스템
# - 해외주식 입력
# - 주식 차입
# - 해외주식 단가변경
# - 해외주식양도세
# - 해외주식 정보력
# - 주식
# - 해외 주식
# - 국내주식
# - 해외주식 프로그램
# - 국내주식 약세장
# - 해외주식 거래
# - 해외주식 단가
# - 주식 주문
# - 주식영업
# - 해외주식 단가입력
# - 해외주식 단가 입력
# - 해외주식
# - 해외주식 이관
#
# 클러스터 127: 대표 키워드 - 전략
# 키워드들:
# - 전략과제
# - 전략 부재
# - 전략방향
# - 전략과제 문제
# - 전략과제 조정
# - 전략과제 관리
# - 상품 전략
#
# 클러스터 81: 대표 키워드 - 융통성
# 키워드들:
# - 융통성 처리
# - 융통성 부족
# - 융통성 결여
# - 융통성
#
# 클러스터 97: 대표 키워드 - 검토
# 키워드들:
# - 프로세스 세부 검토
# - 전반적 재검토
# - 상품검토
#
# 클러스터 50: 대표 키워드 - 지원
# 키워드들:
# - 법카 지원 불공평
# - 고객지원센터
# - 영업지원비
# - 업무 지원 필요
# - 업무 지원 부족
# - 센터장
# - 영업지원
# - 지점 지원
# - 본사 지원
#
# 클러스터 46: 대표 키워드 - 역할
# 키워드들:
# - 책임자 역할
# - 역할 명확화
# - R&R 명확화
# - 관리자 감독 역할
#
# 클러스터 86: 대표 키워드 - 데이터
# 키워드들:
# - 시뮬레이션 화면
# - 시뮬레이션 개선
# - 데이터 정확성
# - 시뮬레이션 데이터
# - 데이터 개선
# - 데이터 정확도
#
# 클러스터 1: 대표 키워드 - 과도
# 키워드들:
# - 과도한 목표
# - 목표 배정 프로세스
# - 과도한 규제
# - 과도한 KPI
# - 목표 과중
# - 과도한 통제
# - 과도한 내부통제
# - 규제
# - 과도한 자금 운용
# - KPI 목표 배정
# - 과도
# - 업무 과중
# - KPI 과도한 목표
# - 목표 유연성
# - 과도한 감사
# - KPI 목표
#
# 클러스터 27: 대표 키워드 - 외부
# 키워드들:
# - 조사
# - 외부조사
# - 전수조사
# - 외부영업
# - 외부 활동 직원 지원 부족
# - 외부활동 위축
# - 외부인사 영입
# - 외부활동
#
# 클러스터 14: 대표 키워드 - 영업
# 키워드들:
# - 영업전환
# - 영업 직무
# - 법인영업 위축
# - 우선순위 처리
# - 무리한 영업
# - 위축
# - 직무전환
# - 영업 유혹
# - 영업사원
# - 영업과 본사 간 괴리
# - 채권영업
# - 영업 방향성
# - 법인영업
# - 영업 우선
# - 영업
# - 영업 직무 전환
# - 영업 위축
# - 대외영업
# - 법인영업 타격
# - 안전한 영업
# - 법인영업센터
# - IB연계 영업
# - KPI 방향성
# - 영업추진부
# - 직무 순환
# - 개인적 영업 타격
# - 파생영업 부서
# - 영업 전환
# - 계좌 전환
# - IB영업
# - 영업 지양
#
# 클러스터 5: 대표 키워드 - 문제
# 키워드들:
# - IT 문제
# - 채권부 수익구조
# - 수익구조 개선
# - 시스템 문제
# - 인센티브 구조 문제
# - 잡음 문제
# - 문제 방지
# - 문제 재발 방지
# - 소음 문제
# - 구조적 문제
# - 지점 구조
# - KPI 문제
# - 주변소음
# - 고객 유도 문제
# - psr 허들 문제
# - 조직적 구조 문제
# - 인력 문제
# - 상품 문제
# - ODS 시스템 잡음
#
# 클러스터 15: 대표 키워드 - 시스템
# 키워드들:
# - 주문시스템
# - S-MEET 시스템
# - 전산 프로그램
# - 업무시스템
# - 업무 시스템
# - 시스템 작동 불가
# - 시스템 개발
# - 시스템화
# - ODS시스템
# - 전산화
# - 시스템
# - 시스템 헛점
# - AI 시스템
# - 전산시스템 불안정
# - ODS 시스템
# - 전산시스템 개선
# - 전산개발
# - 업무 마감 시스템
# - 체크리스트 전산화
# - 팝업 시스템
# - 시스템 개발 필요
# - 평가 시스템
#
# 클러스터 18: 대표 키워드 - 신뢰
# 키워드들:
# - 영업직원
# - 영업직원 역량
# - 고객신뢰 하락
# - 영업직원 신뢰
# - 신뢰 감소
# - 고객 신뢰
# - 심사 신뢰 부족
#
# 클러스터 45: 대표 키워드 - 누락
# 키워드들:
# - 신용만기 안내 누락
# - 권리 누락
# - 신고 누락 리스크
# - 만기 누락
# - 대출 만기 연장
#
# 클러스터 187: 대표 키워드 - 세분
# 키워드들:
# - 업무 세분화
# - 부서 세분화
# - 업무메뉴얼 세분화
# - KPI 세분화
# - 조직 세분화
#
# 클러스터 24: 대표 키워드 - 적용
# 키워드들:
# - 차등 적용
# - BEP 차등 부여
# - 동일 적용
# - 일률적인 절차 적용
#
# 클러스터 48: 대표 키워드 - 사용
# 키워드들:
# - 시스템 사용 부족
# - 시스템 사용 어려움
# - 사용율 낮음
# - MTS 사용 불편
# - 고객 불편
# - 사용할당 과다
# - 회사북 사용
#
# 클러스터 40: 대표 키워드 - 협업
# 키워드들:
# - 외부사 협업 기피
# - 부서별 협업
# - 그룹 협업 부족
# - 협업
# - 협업 강화
# - 협업 문제
#
# 클러스터 103: 대표 키워드 - 성과
# 키워드들:
# - 단기 성과
# - 성과 부서
# - 성과 보상
# - 단기성과 정책
# - 단기성과
# - 영업성과
# - 단기 성과 중심 경력직 채용
# - 조직성과
# - 탐욕과 단기성과주의
# - 단기 성과주의
#
# 클러스터 155: 대표 키워드 - 자료
# 키워드들:
# - 교육자료
# - 자료 발송 시스템
# - 증빙 자료
# - 자료
# - 보고자료 과다 요청
#
# 클러스터 223: 대표 키워드 - 오류
# 키워드들:
# - 명부 오류
# - 오류 발생
# - 관리부서 오류
# - 세액 공제 오류
# - 데이터 오류
# - 폰패드 오류
# - 오류
#
# 클러스터 200: 대표 키워드 - 잔액
# 키워드들:
# - 수기잔액증명서
#
# 클러스터 3: 대표 키워드 - 인계
# 키워드들:
# - 인수인계서
# - 인계인수
# - 일 확대
# - 인수인계 관리
# - 인수인계
# - 인수인계서 확대
#
# 클러스터 13: 대표 키워드 - 인력
# 키워드들:
# - 인력배치
# - 투상 인력
# - 인력배치 문제
# - 외부 인력 관리
# - 인사배치
# - 투상 인력 과다
# - 젊은 인력 구성
# - 인적 구성
# - 인사 부서배치
# - 인사 인력배치
# - 인력 개선
# - 인력관리 개선
# - 인력 배치
# - 인사 재구성
#
# 클러스터 78: 대표 키워드 - 선물옵션
# 키워드들:
# - 선물옵션
# - 법인선물옵션부 문제
# - 선물옵션 담당자
# - 법인선물옵션부 퇴사
# - 선물옵션 전문가
#
# 클러스터 95: 대표 키워드 - 골드
# 키워드들:
# - 골드넷+ 업무
# - 골드넷 승인
# - 골드넷+
# - 골드넷+ 교육
#
# 클러스터 49: 대표 키워드 - 예방
# 키워드들:
# - 사고예방
# - 상품 분쟁 예방
# - 시스템 예방
# - 고객 분쟁
#
# 클러스터 52: 대표 키워드 - 업무
# 키워드들:
# - 업무처리
# - 업무팀
# - 업무 미루기
# - 업무 퀄리티
# - 수기 업무
# - 부서명 변경
# - 질권 업무
# - LP업무
# - 공모주 업무
# - 업무 변경 안내
# - 업무범위
# - 업무처리자
# - 부적절한 업무
# - 업무담당자 변경
# - 업무 처리 개선
# - 업무 배분
# - 업무 변경
# - 업무처리 시스템
# - 내방 업무
# - 수기 처리 업무
# - 수기업무 위험
# - 업무 구분
# - 수기 처리
# - 업무적정
# - 선진행 업무
# - 업무과실
# - 수기처리 업무
# - 업무개발자
# - KPI 변경
#
# 클러스터 164: 대표 키워드 - 기록
# 키워드들:
# - 메신저 기록
#
# 클러스터 57: 대표 키워드 - 판매
# 키워드들:
# - 상품 판매
# - 완전판매 확인
# - 불완전 판매
# - 상품판매 리스크
# - 판매 금지
# - 상품 판매 독려 과도
# - 상품 판매 신뢰
# - 상품 불완전 판매
# - 완전판매 절차
#
# 클러스터 43: 대표 키워드 - 부서
# 키워드들:
# - 법선 수익부서 제외
# - 본사부서 역할
# - 부서간 협력
# - 수익부서 직원 관리
# - 본사부서
# - 수익
# - 본사 부서 업무 중단
# - 본사 부서 갑질
# - 본사 부서 불통
# - 본사 결제부서 인원 충원
# - 부서와의 합의
# - 상품부서
# - 본사부서 전문성
# - KPI 제외
# - 수익율 리스크
# - 수익부서
# - 본사부서 느슨한 내부통제
# - 힘 있는 부서
# - 부서
# - 부서수익
# - 수익부서 지정 문제
#
# 클러스터 34: 대표 키워드 - 자동
# 키워드들:
# - 자동 번역
# - 자동 연장 필요
# - 문자 발송
# - 자동발송
# - 자동이체 환불
#
# 클러스터 59: 대표 키워드 - 지점
# 키워드들:
# - 효율성
# - 지점 축소
# - 지점 내부통제
# - 보라매지점 흡수
# - 지점 담당자 비효율
# - 영업형 지점장
#
# 클러스터 229: 대표 키워드 - 처벌
# 키워드들:
# - 책임자 처벌
# - 강력한 처벌
# - 솜방망이 처벌
#
# 클러스터 178: 대표 키워드 - 야근
# 키워드들:
# - 자발적 야근
#
# 클러스터 6: 대표 키워드 - 사례
# 키워드들:
# - 사고 사례
# - 재무관리부 안내
# - 사례 안내
# - 사례중심교육
#
# 클러스터 32: 대표 키워드 - 책임
# 키워드들:
# - 책임 명문화
# - 책임 의식 부족
# - 지점 책임
# - 책임 환경
# - 책임 회피 응대
# - 본사 부서 책임 회피
# - 책임 회피
# - 책임
# - 기획자 책임
# - 업무 환경
# - 책임소재 불분명
# - 영업 책임
#
# 클러스터 56: 대표 키워드 - 준수
# 키워드들:
# - 윤리준수 교육
# - 선관의무 준수
# - 내부통제 준수
# - 규정 준수
# - 법규준수
#
# 클러스터 247: 대표 키워드 - 사건
# 키워드들:
# - 사건사고
# - 사건내용 안내
# - 사건 반복
#
# 클러스터 4: 대표 키워드 - 조직
# 키워드들:
# - 수직적 조직문화
# - YES맨 문화
# - 관리와 영업 분리
# - 조직문화 개선
# - 조직적 문제
# - 법인전담팀 필요
# - 조직 시스템
# - 조직 개선
# - 전담 조직
# - 조직변경 문제
# - 조직 분리
# - 조직 편성 변경
# - 조직문화
# - 회의감
# - 조직도 개편
# - 조직 슬림화
# - 조직 모니터링
# - 회의 문화
# - 문화 개선
#
# 클러스터 106: 대표 키워드 - 서류
# 키워드들:
# - 서류 문제
# - 서류 간소화
# - 서류간소화
# - 서류 완화
# - 결제 간소화
# - 가입 서류
# - 상품서류 간소화
# - 절차 간소화
# - 가입서류 보관
# - 서류 복잡성
# - 서류 과다
#
# 클러스터 33: 대표 키워드 - 이동
# 키워드들:
# - 리테일 위기
# - 부서 이동 문제
# - 리테일 이동
# - PWM 이동
# - 주기적 인사이동
# - 고객 이동
# - 리테일
#
# 클러스터 58: 대표 키워드 - 장기
# 키워드들:
# - 내부통제 장기 미비
# - 장기근속자
# - 장기근무
# - 롱텀 근무
# - 장기근속
#
# 클러스터 2: 대표 키워드 - 노출
# 키워드들:
# - 리스크 노출
# - 개인정보 보호
# - 개인정보 노출
# - 고객정보
# - 고객정보 노출
#
# 클러스터 110: 대표 키워드 - 절차
# 키워드들:
# - 확인 절차
# - 미비한 업무절차
# - 상품 가입 절차 문제
# - 내부통제 절차
# - 부적절한 업무절차
# - 부적절한 절차
# - 실물이전 절차
# - 절차 문제
# - 부적절한 업무 절차
#
# 클러스터 66: 대표 키워드 - 문서
# 키워드들:
# - 종이서류
# - 문서 스캔
# - 서류 스캔
# - 전자화문서 시스템
# - 전자화 시스템
# - 종이서류 전자화
# - 종이문서 전자화
# - 문서 스캔 기준
# - 문서화
# - 문서 다양성
# - 종이문서
# - 전자화문서
#
# 클러스터 176: 대표 키워드 - 철저
# 키워드들:
# - 불철저
#
# 클러스터 17: 대표 키워드 - 기준
# 키워드들:
# - 불확실성
# - 기준 불확실
# - 명확한 기준 필요
# - 시장 불확실성
# - 기준 불투명
# - 녹취 기준
# - 손익 소급 기준
#
# 클러스터 9: 대표 키워드 - 감사
# 키워드들:
# - 녹취 중복
# - 경영감사
# - 철저한 감사
# - 서류 중복
# - 총체적 감사 필요
# - 지점 감사
# - 중복 감사
# - 불시 감사제도
# - 정상 부서 감사
#
# 클러스터 38: 대표 키워드 - 인사
# 키워드들:
# - 통제 불합리
# - 불합리한 인사
# - 인사 문제
# - 인사부
# - 공정한 인사발령
# - 발령 혜택
# - 부서 발령
# - 인사 불합리
# - 인사 제도
# - 불합리한 관행
# - 인사관리
# - 인사발령
# - 인사 시스템
#
# 클러스터 73: 대표 키워드 - 제안
# 키워드들:
# - 상품제안서 제약
# - 고객 제안 제약
# - 개선 제안
# - 제안서
#
# 클러스터 37: 대표 키워드 - 한도
# 키워드들:
# - 운용한도
# - 한도
# - 한도 부여자
# - 한도 제한
# - 한도 초과
# - KPI 설정
# - 성과한도
# - 한도 설정
#
# 클러스터 90: 대표 키워드 - 부담
# 키워드들:
# - 정신적 부담
# - 심적 부담
# - 업무 부담
#
# 클러스터 29: 대표 키워드 - 관리
# 키워드들:
# - 계좌 개설
# - 관리 영역
# - 비관리계좌
# - 현장 경험
# - 법인계좌
# - 고객관리 연속성
# - 게시판 관리
# - 현장 관리
# - 계좌개설
# - 비관리 계좌
# - 법인계좌 정보 개선
# - 고객관리
# - 관리 계좌
# - 시재관리
# - 관리
# - 계좌 관리 리스크
# - 계좌정보
# - 고객 관리
#
# 클러스터 23: 대표 키워드 - 부족
# 키워드들:
# - 경영진 간섭 부족
# - 리소스 부족
# - 사전적 검열 부족
# - 책임지는 자세 부족
# - 공정성 부족
#
# 클러스터 62: 대표 키워드 - 리스크
# 키워드들:
# - 리스크 제거
# - 리스크 상품
# - 리스크 확인 필요
# - 평판 리스크 하락
# - KPI 리스크
# - 리스크 요인
# - 리스크 확인
# - 시장 리스크 관리
# - 리스크 분석
# - 평판리스크
# - 리스크
# - 리스크 관리
# - 포기 요인
# - 본사 리스크
# - 평판 리스크
# - 양도세 리스크
# - 평판 개선
#
# 클러스터 87: 대표 키워드 - 담당자
# 키워드들:
# - 담당자 찾기
# - 담당자 찾기 어려움
# - 담당자 관리
# - 매뉴얼 최신화
# - 본사 담당자 부재
# - 담당자 최신화
#
# 클러스터 101: 대표 키워드 - 이슈
# 키워드들:
# - 입력 이슈
# - 이슈 사모상품
# - 법률 이슈
# - 이슈 상품
# - KPI 이슈
# - 컴플이슈
# - 사모상품
#
# 클러스터 47: 대표 키워드 - 점검
# 키워드들:
# - 녹취 점검
# - 점검
# - 철저한 점검
# - 프로세스 점검
# - 자금 사용 점검
# - 정밀 점검
# - 정기적 감사
# - 실질적 점검
# - 정기적 점검
#
# 클러스터 55: 대표 키워드 - 전문
# 키워드들:
# - 팀제 필요
# - 전문팀 통합
# - 전문 인력 부재
# - 전문팀제 필요
# - 전문팀 필요
# - 전문 지식
# - 전문 인력 부족
#
# 클러스터 31: 대표 키워드 - 체계
# 키워드들:
# - 체계적인 확립
# - 성과급체계
# - 주기적 보고
# - 보고시스템
# - 관리체계
# - 대직체계
# - 보고체계
# - STR 보고작성 어려움
#
# 클러스터 227: 대표 키워드 - 거래
# 키워드들:
# - OTC 거래
# - 온라인 거래
# - 거래 가능액 감소
# - 채권거래 내역 불일치
# - Back-to-Back 거래
#
# 클러스터 77: 대표 키워드 - 요구
# 키워드들:
# - 경위서 제출 요구
# - 조치 요구
#
# 클러스터 21: 대표 키워드 - 순환
# 키워드들:
# - 순환보직
# - 순환보직 제도
# - 형평성 문제
# - 영업 순환 형평성
# - 순환보직 체계
#
# 클러스터 246: 대표 키워드 - 대응
# 키워드들:
# - 녹록한 대응
# - 대응 시나리오
# - 본사 대응
#
# 클러스터 92: 대표 키워드 - 손실
# 키워드들:
# - 수익 손실
# - 손실
#
# 클러스터 113: 대표 키워드 - 수수료
# 키워드들:
# - 성과수수료
# - 교섭수수료 누락
# - 수수료 경쟁력 문제
# - 수수료 확인
#
# 클러스터 163: 대표 키워드 - 주니어
# 키워드들:
# - 주니어 기회
# - 주니어 충원
#
# 클러스터 44: 대표 키워드 - 체크
# 키워드들:
# - 매매 체크
# - 크로스 체크
# - 부서간 크로스체크
# - 크로스체크
# - 크로스체크 필요
# - 결제내역 크로스체크
# - 체크 누락
# - 체크
#
# 클러스터 174: 대표 키워드 - 영향
# 키워드들:
# - 영향도 큼
#
# 클러스터 172: 대표 키워드 - 호성
# 키워드들:
# - 모호성
#
# 클러스터 71: 대표 키워드 - 통제
# 키워드들:
# - 통제 부족
# - 시스템적 통제
# - 내부 통제
# - 내부 통제 점검
# - 내부 전문가 육성
# - 내부 직원 육성
# - 준법 통제
# - 과한 통제
# - 내부 문제
# - 내부 통제 부족
# - 내부 인재 중용
# - 본사 내부 통제 사고
# - 통제
# - 파생상품 통제
# - 통제 시스템
# - 재무회계 통제
# - 통제 확인 시스템
# - 본사 통제 소홀
#
# 클러스터 93: 대표 키워드 - 라임
# 키워드들:
# - 라임사태
# - 현 사태
# - 라임
#
# 클러스터 124: 대표 키워드 - 서비스
# 키워드들:
# - 고객 서비스
# - 환율우대 서비스
#
# 클러스터 118: 대표 키워드 - 라인
# 키워드들:
# - 결제라인
# - 인사라인 부작용
#
# 클러스터 104: 대표 키워드 - 비밀번호
# 키워드들:
# - 비밀번호 입력
# - 비밀번호 없이 전환
# - 대표비밀번호
#
# 클러스터 75: 대표 키워드 - 인적
# 키워드들:
# - 인적 문제
# - 인적 쇄신
# - 인적쇄신
# - 이미지 쇄신
# - 인적쇄신 필요
#
# 클러스터 170: 대표 키워드 - 고스트
# 키워드들:
# - 고스트PC
#
# 클러스터 91: 대표 키워드 - 압박
# 키워드들:
# - 실적 압박
# - 실적 우수자
# - KPI 압박
# - 실적
# - 압박
#
# 클러스터 94: 대표 키워드 - 검증
# 키워드들:
# - 본사 검증
# - 상품 검증
# - 검증 부족
# - 데이터 검증
# - 철저한 검증과 통제
# - KPI 검증
#
# 클러스터 119: 대표 키워드 - 보완
# 키워드들:
# - 보완
# - 서류 미비
# - 보완기한 준수
# - 보완완료
# - 서류 보완
# - 미비점
# - 미비사항
# - 매뉴얼 미비
# - 보완 충분
# - 미비 보완
# - 미비서류 보완
# - 보완 완료
#
# 클러스터 63: 대표 키워드 - 화면
# 키워드들:
# - 타사 시스템 차이
# - 화면 업데이트
# - 화면 안내
# - 대리인 등록 업데이트
# - 매뉴얼 업데이트
# - 시스템 업데이트
# - 화면 문제
# - 앱 화면
# - 골드넷+ 화면 업데이트
# - HTS 화면 차이
#
# 클러스터 102: 대표 키워드 - 가이드라인
# 키워드들:
# - 투자 권유 가이드라인
# - 광고 가이드라인
#
# 클러스터 168: 대표 키워드 - 수단
# 키워드들:
# - 매수단가
#
# 클러스터 74: 대표 키워드 - 민원
# 키워드들:
# - 민원 발생
# - 민원
# - 금융감독원 민원
# - 민원 발생 가능
# - 고객 민원
#
# 클러스터 111: 대표 키워드 - 성과급
# 키워드들:
# - 성과급제도
# - 성과급 회수
# - 성과급 연동
# - 연동 문제
# - 성과급 문제
#
# 클러스터 36: 대표 키워드 - 이자
# 키워드들:
# - 이자 산정
# - 채권 이자 지급
# - 이자 미납
#
# 클러스터 217: 대표 키워드 - 시니어
# 키워드들:
# - 시니어
# - 시니어부족
# - 시니어급 내부통제
#
# 클러스터 7: 대표 키워드 - 필요
# 키워드들:
# - 게시물 필요
# - 보강 필요
# - 조직개편
# - 알럿 필요
# - 조직개편 필요
#
# 클러스터 243: 대표 키워드 - 계약
# 키워드들:
# - 계약 과정
# - 계약 관리
#
# 클러스터 85: 대표 키워드 - 저하
# 키워드들:
# - 동기부여 부족
# - 저하
# - 동기부여 저하
# - 사기 저하
# - 영업력 저하
#
# 클러스터 203: 대표 키워드 - 연금
# 키워드들:
# - 연금 해지 계좌
# - 연금저출 시스템
# - 퇴직연금 화면 개선
# - 연금저축
# - 개인연금
# - 퇴직연금
# - 퇴직연금 매도업무
# - 퇴직연금업무
# - 연금 업무
# - 퇴직연금 시스템
#
# 클러스터 116: 대표 키워드 - 집중
# 키워드들:
# - 파워 집중
# - 업무집중화팀
# - 권한 집중
# - 디지털집중화팀
# - 콜 집중화
#
# 클러스터 211: 대표 키워드 - 담보
# 키워드들:
# - 무담보 미수채권 관리
# - 담보 관리
# - 담보부족
# - 담보리스크
# - 주식담보 대출
#
# 클러스터 199: 대표 키워드 - 센티
# 키워드들:
# - 팀 인센티브 제도
# - 인센티브
# - 인센티브 관리
# - 인센티브 문제
# - 인센티브 지급
#
# 클러스터 65: 대표 키워드 - 파악
# 키워드들:
# - 상황 파악
# - 현황 파악
#
# 클러스터 98: 대표 키워드 - 증권
# 키워드들:
# - 미래에셋증권
# - 증권 본업
# - 증권사관학교
#
# 클러스터 114: 대표 키워드 - 중심
# 키워드들:
# - 고객중심
# - 수익 중심주의
# - 수익 중심 경영
# - 고객 중심
# - 시장중심
#
# 클러스터 20: 대표 키워드 - 권한
# 키워드들:
# - PB 권한
# - 내부통제 권한 부족
# - 업무 권한 과다
# - 컨트롤타워 권한
# - 권한 통제
# - 권한 부여자
# - 권한
# - 컨트롤타워 조직
#
# 클러스터 143: 대표 키워드 - 관행
# 키워드들:
# - 주문 관행
# - 메신저 처리 관행
# - 부적절한 관행
# - 관행적 절차
# - 조직 부정적 관행
#
# 클러스터 109: 대표 키워드 - 처리
# 키워드들:
# - 큰 금액 처리
# - 수동 처리
# - 고객 방문 처리
#
# 클러스터 207: 대표 키워드 - 부재
# 키워드들:
# - 시스템 부재
# - 대직자 부재
# - 팀장 부재
# - 관리 시스템 부재
# - 기준 부재
# - 리더십 부재
# - 운용역 부재
# - 책임자 부재
#
# 클러스터 25: 대표 키워드 - 사고
# 키워드들:
# - 사고 위험성
# - 금융 사고
# - 사고상품 관리
# - 사고발생 확률
# - 위험성
# - 자금 사고
# - 본사 사고
# - 문제 발생
# - 금융사고
# - GIB 사고
# - 사고 발생
# - 사고
# - 리스크 발생
#
# 클러스터 206: 대표 키워드 - 어려움
# 키워드들:
# - 업무 어려움
# - 답변 어려움
# - 통화 어려움
# - 영업 어려움
# - 통제 어려움
# - 업무처리 어려움
# - 영업환경 어려움
# - 어려움
#
# 클러스터 166: 대표 키워드 - 법무
# 키워드들:
# - 법무실
#
# 클러스터 117: 대표 키워드 - 예외
# 키워드들:
# - 예외연장 기준
# - 예외적 업무
# - 예외 부서 점검
# - 예외업무 매뉴얼
#
# 클러스터 69: 대표 키워드 - 제도
# 키워드들:
# - 정부제도
# - 숙려제도
#
# 클러스터 51: 대표 키워드 - 구축
# 키워드들:
# - 관계 확인
# - 신뢰관계 구축
# - 시스템 구축
#
# 클러스터 159: 대표 키워드 - 지시
# 키워드들:
# - 상급자 지시 문제
# - 강압적 지시
# - 부당한 지시
#
# 클러스터 188: 대표 키워드 - 일시
# 키워드들:
# - 일시적 중단
#
# 클러스터 79: 대표 키워드 - 투명
# 키워드들:
# - 업무능력 향상
# - 정보 투명성
# - 투명성 향상
#
# 클러스터 122: 대표 키워드 - 개인
# 키워드들:
# - 개인 역량
# - 개인 포기
#
# 클러스터 135: 대표 키워드 - 공개
# 키워드들:
# - 투명한 공개
# - 최종 결론 공개
# - 정보 공개
# - 필벌 내용 공개
#
# 클러스터 35: 대표 키워드 - 매뉴얼
# 키워드들:
# - 매뉴얼 부족
# - 접근 불가
# - 망고매뉴얼
# - 매뉴얼 등재 누락
# - 가이드 매뉴얼
# - 매뉴얼 등재
# - 업무매뉴얼 필요
# - 매뉴얼 정비
# - 업무매뉴얼 부족
# - 매뉴얼
# - 가이드 부족
# - 업무 가이드
# - 매뉴얼 접근
# - 업무 매뉴얼
# - 법인금융 업무 매뉴얼
#
# 클러스터 165: 대표 키워드 - 해석
# 키워드들:
# - 명확한 해석
#
# 클러스터 162: 대표 키워드 - 노력
# 키워드들:
# - 인당 노력
#
# 클러스터 160: 대표 키워드 - 가격
# 키워드들:
# - 매수가격
#
# 클러스터 54: 대표 키워드 - 매매
# 키워드들:
# - 오프라인 매매
# - 오프라인 고객
# - 매매주문
# - 임직원 자기매매
# - 무리한 매매
# - 고객계좌 임의매매
# - 본인계좌 매매
# - 매매시스템
#
# 클러스터 158: 대표 키워드 - 경향
# 키워드들:
# - 부적절한 경향
#
# 클러스터 123: 대표 키워드 - 회수
# 키워드들:
# - 회수불가
# - 미수채권 회수
# - 채권 회수 전담팀
# - 교육 회수
#
# 클러스터 89: 대표 키워드 - 소통
# 키워드들:
# - 세대 간 소통
# - CEO 소통
# - 정보 소통
# - 소통 문제
# - 소통 어려움
# - 고객 소통
#
# 클러스터 221: 대표 키워드 - 변화
# 키워드들:
# - 경영진 변화 필요
# - 제도적 변화
# - 시장 변화
# - 변화 없음
# - 인식 변화
#
# 클러스터 237: 대표 키워드 - 전문가
# 키워드들:
# - 전문가 배치
# - 전문가 필요
# - 전문가 부재
# - 전문가 영업
# - 전문가 부족
#
# 클러스터 156: 대표 키워드 - 더블
# 키워드들:
# - 더블카운팅
#
# 클러스터 60: 대표 키워드 - 운영
# 키워드들:
# - 운영리스크
# - 지점 운영
# - 고유자금 운영
#
# 클러스터 231: 대표 키워드 - 형식
# 키워드들:
# - 형식적 관행
# - 형식적 승인
# - 형식적 통제
# - 형식적
# - 형식적 점검
#
# 클러스터 214: 대표 키워드 - 위험
# 키워드들:
# - 위험
# - 고지팀
# - 위험 고지
# - 위험도 정보
#
# 클러스터 53: 대표 키워드 - 법인
# 키워드들:
# - 법인카드
# - 법인카드 리스크
# - 법인카드 사용 통제
# - 법인자금 유출
# - 정보 유출 리스크
# - 법인 비딩
#
# 클러스터 186: 대표 키워드 - 감점
# 키워드들:
# - KPI 감점 가능성
#
# 클러스터 213: 대표 키워드 - 세금
# 키워드들:
# - 세금 관련 입금
# - 세금 관련 프로세스
# - 세금 문제
#
# 클러스터 209: 대표 키워드 - 대비
# 키워드들:
# - 대비
# - 타사 대비
#
# 클러스터 115: 대표 키워드 - 인감
# 키워드들:
# - 법인 인감
# - 사용인감 효력
# - 인감
#
# 클러스터 205: 대표 키워드 - 시간
# 키워드들:
# - 시간 소요
# - 투자 시간
# - 시간 소모
# - 대출업무 시간
#
# 클러스터 183: 대표 키워드 - 자산
# 키워드들:
# - 고객 자산
# - 고유자산
# - 자산 유출
#
# 클러스터 245: 대표 키워드 - 열사
# 키워드들:
# - 계열사 업무
# - 신한계열사 입금
#
# 클러스터 154: 대표 키워드 - 상담
# 키워드들:
# - 상담일지
#
# 클러스터 107: 대표 키워드 - 승인
# 키워드들:
# - 처리 지연
# - 심사부 승인 지연
# - 업무처리 지연
# - 승인 프로세스
# - 책임자 승인
# - CDD 승인 지연
# - 승인 절차
# - 책임자 승인 프로세스
# - 부서 응답 지연
# - 승인 처리
# - 지연
#
# 클러스터 180: 대표 키워드 - 방식
# 키워드들:
# - 쪽지 전달방식
#
# 클러스터 152: 대표 키워드 - 친밀
# 키워드들:
# - 친밀감
#
# 클러스터 100: 대표 키워드 - 창구
# 키워드들:
# - 디지털창구
# - 고객 창구 대기
#
# 클러스터 150: 대표 키워드 - 난국
# 키워드들:
# - 난국
#
# 클러스터 171: 대표 키워드 - 금리
# 키워드들:
# - 채권금리
# - 협의금리
# - 금리 경쟁력
#
# 클러스터 201: 대표 키워드 - 엑셀
# 키워드들:
# - 엑셀
# - 엑셀 업로드
#
# 클러스터 191: 대표 키워드 - 설명
# 키워드들:
# - 설명 부족
# - 고객 설명
# - 상품 설명
#
# 클러스터 238: 대표 키워드 - 등록
# 키워드들:
# - 매뉴얼 등록
# - 전문투자자 등록
# - 유치자 등록
#
# 클러스터 148: 대표 키워드 - 모범
# 키워드들:
# - 모범
#
# 클러스터 146: 대표 키워드 - 로테이션
# 키워드들:
# - 로테이션
#
# 클러스터 83: 대표 키워드 - 기능
# 키워드들:
# - 시스템 알람 기능
# - 알람
# - 녹음기능
# - 시스템 감시 기능
#
# 클러스터 144: 대표 키워드 - 우울
# 키워드들:
# - 우울감
#
# 클러스터 142: 대표 키워드 - 부적합
# 키워드들:
# - 시점 부적합
#
# 클러스터 140: 대표 키워드 - 개별
# 키워드들:
# - 개별 공시
#
# 클러스터 138: 대표 키워드 - 대량
# 키워드들:
# - 대량 메일
#
# 클러스터 136: 대표 키워드 - 의혹
# 키워드들:
# - 카르텔 의혹
#
# 클러스터 134: 대표 키워드 - 온도
# 키워드들:
# - 온도차
#
# 클러스터 235: 대표 키워드 - 추가
# 키워드들:
# - 기능 추가
# - 업무 추가
# - 추가 통제 불필요
#
# 클러스터 132: 대표 키워드 - 출장
# 키워드들:
# - 출장
#
# 클러스터 219: 대표 키워드 - 견제
# 키워드들:
# - 부서 견제
# - 견제와 균형
# - 견제 시스템
#
# 클러스터 41: 대표 키워드 - 임원
# 키워드들:
# - 임원 모럴헤저드
# - 임원 균형
# - 임원 솔선수범
# - 모럴헤저드
# - 임원 사명감
#
# 클러스터 121: 대표 키워드 - 결재
# 키워드들:
# - 결재 시스템
# - 결재 편의성
# - 결재 위임
# - 결재 절차
#
# 클러스터 130: 대표 키워드 - 미반
# 키워드들:
# - KPI 미반영
#
# 클러스터 151: 대표 키워드 - 전자문서
# 키워드들:
# - 전자문서 고도화
# - 전자문서 시스템
# - 전자문서
#
# 클러스터 233: 대표 키워드 - 이해
# 키워드들:
# - 이해 어려움
# - 현장 이해 부족
# - 이해상충
# - 업무 프로세스 이해
# - 내부통제 이해 부족
#
# 클러스터 128: 대표 키워드 - 그레이
# 키워드들:
# - 그레이존
#
# 클러스터 39: 대표 키워드 - 단가
# 키워드들:
# - 단가 입력
# - 단가 입력 프로세스
# - 단가 수작업
# - 수작업
# - 단가 수기입력
#
# 클러스터 96: 대표 키워드 - 무시
# 키워드들:
# - 실무자 의견 무시
# - 무시
# - 지점 특성 무시
#
# 클러스터 22: 대표 키워드 - 신규
# 키워드들:
# - 신규고객
# - 신규 채용
# - 자기사람 채용
#
# 클러스터 126: 대표 키워드 - 마스
# 키워드들:
# - 주민번호 마스킹
#
# 클러스터 239: 대표 키워드 - 외국인
# 키워드들:
# - 거주외국인
# - 외국인 업무
#
# 클러스터 248: 대표 키워드 - 성장
# 키워드들:
# - 지속 성장
#
# 클러스터 244: 대표 키워드 - 언론보도
# 키워드들:
# - 언론보도
#
# 클러스터 240: 대표 키워드 - 경쟁
# 키워드들:
# - 경쟁사
#
# 클러스터 236: 대표 키워드 - 책임감
# 키워드들:
# - 책임감
#
# 클러스터 232: 대표 키워드 - 벤치마킹
# 키워드들:
# - 벤치마킹
#
# 클러스터 228: 대표 키워드 - 이용
# 키워드들:
# - SNS 이용
#
# 클러스터 198: 대표 키워드 - 날인
# 키워드들:
# - 전자직인 날인
# - 날인
#
# 클러스터 224: 대표 키워드 - 수익금
# 키워드들:
# - 수익금
#
# 클러스터 84: 대표 키워드 - 체제
# 키워드들:
# - 2인 체제
# - 3인 체제
#
# 클러스터 220: 대표 키워드 - 신입사원
# 키워드들:
# - 신입사원
#
# 클러스터 216: 대표 키워드 - 대체
# 키워드들:
# - 예수금 대체
#
# 클러스터 212: 대표 키워드 - 컴플라이언스
# 키워드들:
# - 컴플라이언스
#
# 클러스터 208: 대표 키워드 - 포상
# 키워드들:
# - 포상
#
# 클러스터 167: 대표 키워드 - 주의
# 키워드들:
# - 온정주의
# - 보신주의
# - 안정주의
#
# 클러스터 204: 대표 키워드 - 문제점
# 키워드들:
# - 문제점
#
# 클러스터 99: 대표 키워드 - 설계
# 키워드들:
# - 설계단계
# - 잘못 설계
#
# 클러스터 196: 대표 키워드 - 모욕
# 키워드들:
# - 모욕
#
# 클러스터 192: 대표 키워드 - 만족
# 키워드들:
# - 만족
#
# 클러스터 190: 대표 키워드 - 단순화
# 키워드들:
# - 단순화
#
# 클러스터 184: 대표 키워드 - 적극
# 키워드들:
# - 적극적 해결
#
# 클러스터 182: 대표 키워드 - 헤리티지
# 키워드들:
# - 헤리티지
#
# 클러스터 177: 대표 키워드 - 이메일
# 키워드들:
# - 이메일
#
# 클러스터 169: 대표 키워드 - 고충
# 키워드들:
# - 고충
#
# 클러스터 108: 대표 키워드 - 전문성
# 키워드들:
# - 전문성 부족
# - 업무전문성
# - 부서장 전문성
# - 전문성 부족 인사 이동
#
# 클러스터 125: 대표 키워드 - 선물
# 키워드들:
# - 해외선물
# - 선물/옵션
#
# 클러스터 82: 대표 키워드 - 이어폰
# 키워드들:
# - 이어폰
#
# 클러스터 67: 대표 키워드 - 정책
# 키워드들:
# - KPI 일관성
# - 운영정책
# - KPI 정책
# - 정책
# - 정책 변화
# - 정책 일관성
#
# 클러스터 189: 대표 키워드 - 브랜드
# 키워드들:
# - 브랜드 혜택
#
# 클러스터 157: 대표 키워드 - 상승
# 키워드들:
# - BEP 상승
#
# 클러스터 175: 대표 키워드 - 성향
# 키워드들:
# - 투자상담사
# - 투자성향 정보
# - 개인성향
# - 투자성향지 문제
#
# 클러스터 153: 대표 키워드 - 행정
# 키워드들:
# - 보여주기식 행정
#
# 클러스터 12: 대표 키워드 - 회사
# 키워드들:
# - 좋은 분위기
# - 본사 분위기
# - 회사 정상화
# - 회사 위상
# - 회사애정
# - 회사 분위기
#
# 클러스터 149: 대표 키워드 - 예시
# 키워드들:
# - 예시글 제공
#
# 클러스터 120: 대표 키워드 - 대안
# 키워드들:
# - 대안 부족
# - 대안
#
# 클러스터 195: 대표 키워드 - 일원화
# 키워드들:
# - 안내 일원화
# - 매뉴얼 일원화
# - 업무 일원화 필요
# - 시스템 일원화
# - 일원화
#
# 클러스터 145: 대표 키워드 - 달성
# 키워드들:
# - KPI 달성
#
# 클러스터 193: 대표 키워드 - 점심시간
# 키워드들:
# - 점심시간
# - 점심시간 교대
#
# 클러스터 137: 대표 키워드 - 상부
# 키워드들:
# - 투상부 적극성
#
# 클러스터 133: 대표 키워드 - 기간
# 키워드들:
# - 유예기간
#
# 클러스터 129: 대표 키워드 - 재고
# 키워드들:
# - KPI 재고
#
# 클러스터 250: 대표 키워드 - 보관
# 키워드들:
# - 보관
#
# 클러스터 249: 대표 키워드 - 사후관리
# 키워드들:
# - 사후관리
#
# 클러스터 242: 대표 키워드 - 연구
# 키워드들:
# - 정서적 연구
#
# 클러스터 234: 대표 키워드 - 노동조합
# 키워드들:
# - 노동조합
#
# 클러스터 222: 대표 키워드 - 미흡
# 키워드들:
# - 본사 내부통제 미흡
# - 미흡
# - 매뉴얼 미흡
#
# 클러스터 226: 대표 키워드 - 차단
# 키워드들:
# - 활용 차단
#
# 클러스터 218: 대표 키워드 - 실명
# 키워드들:
# - 실명제
#
# 클러스터 194: 대표 키워드 - 덕성
# 키워드들:
# - 비도덕성
#
# 클러스터 185: 대표 키워드 - 포용
# 키워드들:
# - 포용
#
# 클러스터 173: 대표 키워드 - 권위
# 키워드들:
# - 권위적 PB
#
# 클러스터 161: 대표 키워드 - 미스터리
# 키워드들:
# - 미스터리쇼핑
#
# 클러스터 76: 대표 키워드 - 이율
# 키워드들:
# - 이율
#
# 클러스터 72: 대표 키워드 - 빡빡
# 키워드들:
# - 빡빡함
#
# 클러스터 141: 대표 키워드 - 참고
# 키워드들:
# - 타사 참고
#
# 클러스터 64: 대표 키워드 - 표준화
# 키워드들:
# - 표준화
#
# 클러스터 241: 대표 키워드 - 공모
# 키워드들:
# - 공모 의심
#
# 클러스터 225: 대표 키워드 - 계산
# 키워드들:
# - 증거금계산
#
# 클러스터 202: 대표 키워드 - 묵인
# 키워드들:
# - 묵인
#
# 클러스터 112: 대표 키워드 - 조정
# 키워드들:
# - KPI 조정
#
# 클러스터 181: 대표 키워드 - 발행
# 키워드들:
# - 발행어음
#
# 클러스터 80: 대표 키워드 - 강점
# 키워드들:
# - 강점
#
# 클러스터 147: 대표 키워드 - 트라우마
# 키워드들:
# - 트라우마
#
# 클러스터 230: 대표 키워드 - 드라이브
# 키워드들:
# - KPI 드라이브
#
# 클러스터 210: 대표 키워드 - 의사소통
# 키워드들:
# - 의사소통
#
# 클러스터 88: 대표 키워드 - 내부고발자
# 키워드들:
# - 내부고발자
#
# 클러스터 68: 대표 키워드 - 각심
# 키워드들:
# - 경각심
#
# 클러스터 131: 대표 키워드 - 불명
# 키워드들:
# - 불명확성

# %%
file_path = './file/설문 정리.xlsx'
with pd.ExcelWriter(file_path, engine='xlsxwriter') as writer:
    df.to_excel(writer, sheet_name='idx_요약-키워드', index=False)
    df_keyword.to_excel(writer, sheet_name='idx_키워드', index=False)
    df_result.to_excel(writer, sheet_name='키워드 현황', index=False)

# df_result.to_excel("./키워드 현황.xlsx")
